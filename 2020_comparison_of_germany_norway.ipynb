# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price_df_2020 = pd.read_excel("/content/Gro_handelspreise_202001010000_202012312359.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
price_df_2020.head(8)
# Out:
#                  Datenkategorie: Großhandelspreise Unnamed: 1  \
# 0                                       Region: DE        NaN
# 1  Zeitraum: 01.01.2020, 00:00 - 31.12.2020, 23:59        NaN
# 2                         Stand: 04.05.2022, 00:53        NaN
# 3                 (c) Bundesnetzagentur | SMARD.de        NaN
# 4                                              NaN        NaN
# 5                                            Datum    Uhrzeit
# 6                                       01.01.2020      00:00
# 7                                       01.01.2020      01:00
#
#                      Unnamed: 2         Unnamed: 3         Unnamed: 4  \
# 0                           NaN                NaN                NaN
# 1                           NaN                NaN                NaN
# 2                           NaN                NaN                NaN
# 3                           NaN                NaN                NaN
# 4                           NaN                NaN                NaN
# 5  Deutschland/Luxemburg[€/MWh]  Dänemark 1[€/MWh]  Dänemark 2[€/MWh]
# 6                         41.88              33.42              33.42
# 7                          38.6              31.77              31.77
#
#           Unnamed: 5             Unnamed: 6          Unnamed: 7    Unnamed: 8  \
# 0                NaN                    NaN                 NaN           NaN
# 1                NaN                    NaN                 NaN           NaN
# 2                NaN                    NaN                 NaN           NaN
# 3                NaN                    NaN                 NaN           NaN
# 4                NaN                    NaN                 NaN           NaN
# 5  Frankreich[€/MWh]  Italien (Nord)[€/MWh]  Niederlande[€/MWh]  Polen[€/MWh]
# 6              41.88                  41.88               41.88         34.95
# 7               38.6                   38.6                38.6         34.67
#
#           Unnamed: 9     Unnamed: 10       Unnamed: 11        Unnamed: 12  \
# 0                NaN             NaN               NaN                NaN
# 1                NaN             NaN               NaN                NaN
# 2                NaN             NaN               NaN                NaN
# 3                NaN             NaN               NaN                NaN
# 4                NaN             NaN               NaN                NaN
# 5  Schweden 4[€/MWh]  Schweiz[€/MWh]  Slowenien[€/MWh]  Tschechien[€/MWh]
# 6              28.78           35.42             41.88               33.2
# 7              28.45           34.04              38.6               30.4
#
#      Unnamed: 13        Unnamed: 14      Unnamed: 15     Unnamed: 16  \
# 0            NaN                NaN              NaN             NaN
# 1            NaN                NaN              NaN             NaN
# 2            NaN                NaN              NaN             NaN
# 3            NaN                NaN              NaN             NaN
# 4            NaN                NaN              NaN             NaN
# 5  Ungarn[€/MWh]  Österreich[€/MWh]  DE/AT/LU[€/MWh]  Belgien[€/MWh]
# 6          33.55              41.88                -           41.88
# 7           30.4               38.6                -            38.6
#
#          Unnamed: 17
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5  Norwegen 2[€/MWh]
# 6              31.82
# 7              31.77

# %%
price_df_2020_ger = price_df_2020.iloc[5:,:3]

# %%
price_df_2020_ger
# Out:
#      Datenkategorie: Großhandelspreise Unnamed: 1  \
# 5                                Datum    Uhrzeit
# 6                           01.01.2020      00:00
# 7                           01.01.2020      01:00
# 8                           01.01.2020      02:00
# 9                           01.01.2020      03:00
# ...                                ...        ...
# 8785                        31.12.2020      19:00
# 8786                        31.12.2020      20:00
# 8787                        31.12.2020      21:00
# 8788                        31.12.2020      22:00
# 8789                        31.12.2020      23:00
#
#                         Unnamed: 2
# 5     Deutschland/Luxemburg[€/MWh]
# 6                            41.88
# 7                             38.6
# 8                            36.55
# 9                            32.32
# ...                            ...
# 8785                         59.47
# 8786                          56.7
# 8787                         52.44
# 8788                         51.86
# 8789                         52.26
#
# [8785 rows x 3 columns]

# %%
price_df_2020_ger=price_df_2020_ger.rename(columns={'Datenkategorie: Großhandelspreise':"Date","Unnamed: 1":"Time","Unnamed: 2":"Deutschland/Luxemburg[€/MWh]"})

# %%
price_df_2020_ger.drop(5,axis=0,inplace =True)
price_df_2020_ger
# Out:
#             Date   Time Deutschland/Luxemburg[€/MWh]
# 6     01.01.2020  00:00                        41.88
# 7     01.01.2020  01:00                         38.6
# 8     01.01.2020  02:00                        36.55
# 9     01.01.2020  03:00                        32.32
# 10    01.01.2020  04:00                        30.85
# ...          ...    ...                          ...
# 8785  31.12.2020  19:00                        59.47
# 8786  31.12.2020  20:00                         56.7
# 8787  31.12.2020  21:00                        52.44
# 8788  31.12.2020  22:00                        51.86
# 8789  31.12.2020  23:00                        52.26
#
# [8784 rows x 3 columns]

# %%
price_df_2020_ger
# Out:
#             Date   Time Deutschland/Luxemburg[€/MWh]
# 6     01.01.2020  00:00                        41.88
# 7     01.01.2020  01:00                         38.6
# 8     01.01.2020  02:00                        36.55
# 9     01.01.2020  03:00                        32.32
# 10    01.01.2020  04:00                        30.85
# ...          ...    ...                          ...
# 8785  31.12.2020  19:00                        59.47
# 8786  31.12.2020  20:00                         56.7
# 8787  31.12.2020  21:00                        52.44
# 8788  31.12.2020  22:00                        51.86
# 8789  31.12.2020  23:00                        52.26
#
# [8784 rows x 3 columns]

# %%
price_df_2020_ger.isnull().sum()
# Out:
# Date                            0
# Time                            0
# Deutschland/Luxemburg[€/MWh]    0
# dtype: int64

# %%
price_df_2020_ger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8784 entries, 6 to 8789
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          8784 non-null   object
#  1   Time                          8784 non-null   object
#  2   Deutschland/Luxemburg[€/MWh]  8784 non-null   object
# dtypes: object(3)
# memory usage: 274.5+ KB

# %%
price_df_2020_ger["Deutschland/Luxemburg[€/MWh]"] = price_df_2020_ger["Deutschland/Luxemburg[€/MWh]"].astype(float)

# %%
price_df_2020_ger.describe()
# Out:
#        Deutschland/Luxemburg[€/MWh]
# count                   8784.000000
# mean                      30.470715
# std                       17.500846
# min                      -83.940000
# 25%                       21.750000
# 50%                       30.990000
# 75%                       40.250000
# max                      200.040000

# %%
dt_series = price_df_2020_ger['Date'] + ' ' + pd.Series(data=[str(item).replace(".", ":") for item in price_df_2020_ger['Time']], index=price_df_2020_ger.index)
dt_series = pd.to_datetime(dt_series)
dt_series
# Out:
# 6      2020-01-01 00:00:00
# 7      2020-01-01 01:00:00
# 8      2020-01-01 02:00:00
# 9      2020-01-01 03:00:00
# 10     2020-01-01 04:00:00
#                ...
# 8785   2020-12-31 19:00:00
# 8786   2020-12-31 20:00:00
# 8787   2020-12-31 21:00:00
# 8788   2020-12-31 22:00:00
# 8789   2020-12-31 23:00:00
# Length: 8784, dtype: datetime64[ns]

# %%
df = price_df_2020_ger.drop(columns=['Date', 'Time'], axis=1)
df.insert(loc=0, column='DateTime', value=dt_series)
df
# Out:
#                 DateTime  Deutschland/Luxemburg[€/MWh]
# 6    2020-01-01 00:00:00                         41.88
# 7    2020-01-01 01:00:00                         38.60
# 8    2020-01-01 02:00:00                         36.55
# 9    2020-01-01 03:00:00                         32.32
# 10   2020-01-01 04:00:00                         30.85
# ...                  ...                           ...
# 8785 2020-12-31 19:00:00                         59.47
# 8786 2020-12-31 20:00:00                         56.70
# 8787 2020-12-31 21:00:00                         52.44
# 8788 2020-12-31 22:00:00                         51.86
# 8789 2020-12-31 23:00:00                         52.26
#
# [8784 rows x 2 columns]

# %%
plt.figure(figsize=(10,8))
plt.scatter(df["DateTime"],df["Deutschland/Luxemburg[€/MWh]"])
plt.savefig("before of group germany")

# %%
df.hist(column='Deutschland/Luxemburg[€/MWh]')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed2ef46090>]],
#       dtype=object)

# %%
sns.distplot(df['Deutschland/Luxemburg[€/MWh]'])
plt.savefig("Distributionplot for german price data ")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
year_series = dt_series.dt.year
month_series = dt_series.dt.month
day_series = dt_series.dt.day
day_name_series = dt_series.dt.day_name()

# %%
df['Year'] = year_series
df['Month'] = month_series
df['Day'] = day_series
df['Day Name'] = day_name_series

# %%
df = df.sort_values(by='DateTime')
df
# Out:
#                 DateTime  Deutschland/Luxemburg[€/MWh]  Year  Month  Day  \
# 6    2020-01-01 00:00:00                         41.88  2020      1    1
# 7    2020-01-01 01:00:00                         38.60  2020      1    1
# 8    2020-01-01 02:00:00                         36.55  2020      1    1
# 9    2020-01-01 03:00:00                         32.32  2020      1    1
# 10   2020-01-01 04:00:00                         30.85  2020      1    1
# ...                  ...                           ...   ...    ...  ...
# 8785 2020-12-31 19:00:00                         59.47  2020     12   31
# 8786 2020-12-31 20:00:00                         56.70  2020     12   31
# 8787 2020-12-31 21:00:00                         52.44  2020     12   31
# 8788 2020-12-31 22:00:00                         51.86  2020     12   31
# 8789 2020-12-31 23:00:00                         52.26  2020     12   31
#
#        Day Name
# 6     Wednesday
# 7     Wednesday
# 8     Wednesday
# 9     Wednesday
# 10    Wednesday
# ...         ...
# 8785   Thursday
# 8786   Thursday
# 8787   Thursday
# 8788   Thursday
# 8789   Thursday
#
# [8784 rows x 6 columns]

# %%
plt.figure(figsize=(10,8))
plt.scatter(df["Month"],df["Deutschland/Luxemburg[€/MWh]"])
plt.savefig("after grouping the months")

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df["Month"],df["Deutschland/Luxemburg[€/MWh]"])
plt.title("Monthwise boxplot for German Price Day ahead")
plt.savefig("outliners")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
group_month = df.groupby(by='Month',as_index = False)
group_month

# %%
import missingno as msno
msno.bar(df)
plt.savefig("missing value for price german")

# %%
group_month.describe()
# Out:
#    Deutschland/Luxemburg[€/MWh]                                                \
#                           count       mean        std    min      25%     50%
# 0                         744.0  32.243898  16.000454 -48.17  25.0075  33.250
# 1                         696.0  26.817241  18.869329 -32.14  15.7225  27.405
# 2                         743.0  23.894778  14.118996 -55.05  17.5250  24.530
# 3                         720.0  20.556000  19.128350 -83.94  14.8475  21.865
# 4                         744.0  20.828374  18.428701 -74.97  15.4700  22.015
# 5                         720.0  28.469792  11.458019  -4.90  21.5450  30.020
# 6                         744.0  32.456626  11.137667 -44.97  26.0375  32.160
# 7                         744.0  34.884220  13.866203 -16.18  27.5500  33.455
# 8                         720.0  41.457958  21.240770 -58.80  31.2275  39.615
# 9                         745.0  34.587369  15.668929 -16.16  27.0700  34.130
# 10                        720.0  35.908306  16.169875  -5.29  26.9225  36.090
# 11                        744.0  33.439395  17.715261 -33.58  23.4625  35.620
#
#                       Year          ... Month          Day             \
#         75%     max  count    mean  ...   75%   max  count       mean
# 0   42.1000   77.98  744.0  2020.0  ...   1.0   1.0  744.0  16.000000
# 1   37.0025  110.56  696.0  2020.0  ...   2.0   2.0  696.0  15.000000
# 2   32.7200   66.01  743.0  2020.0  ...   3.0   3.0  743.0  15.982503
# 3   29.0350   69.68  720.0  2020.0  ...   4.0   4.0  720.0  15.500000
# 4   30.2400   58.00  744.0  2020.0  ...   5.0   5.0  744.0  16.000000
# 5   36.0575   56.52  720.0  2020.0  ...   6.0   6.0  720.0  15.500000
# 6   39.0725   65.05  744.0  2020.0  ...   7.0   7.0  744.0  16.000000
# 7   41.7775   90.00  744.0  2020.0  ...   8.0   8.0  744.0  16.000000
# 8   49.1625  200.04  720.0  2020.0  ...   9.0   9.0  720.0  15.500000
# 9   43.4000  105.41  745.0  2020.0  ...  10.0  10.0  745.0  16.012081
# 10  45.4875  110.13  720.0  2020.0  ...  11.0  11.0  720.0  15.500000
# 11  46.3525   78.68  744.0  2020.0  ...  12.0  12.0  744.0  16.000000
#
#
#          std  min  25%   50%   75%   max
# 0   8.950289  1.0  8.0  16.0  24.0  31.0
# 1   8.372617  1.0  8.0  15.0  22.0  29.0
# 2   8.943577  1.0  8.0  16.0  24.0  31.0
# 3   8.661458  1.0  8.0  15.5  23.0  30.0
# 4   8.950289  1.0  8.0  16.0  24.0  31.0
# 5   8.661458  1.0  8.0  15.5  23.0  30.0
# 6   8.950289  1.0  8.0  16.0  24.0  31.0
# 7   8.950289  1.0  8.0  16.0  24.0  31.0
# 8   8.661458  1.0  8.0  15.5  23.0  30.0
# 9   8.950348  1.0  8.0  16.0  24.0  31.0
# 10  8.661458  1.0  8.0  15.5  23.0  30.0
# 11  8.950289  1.0  8.0  16.0  24.0  31.0
#
# [12 rows x 32 columns]

# %%
group_month.agg(func=['mean', 'std', 'median'])
# Out:
#       Deutschland/Luxemburg[€/MWh]                       Year               \
#                               mean        std  median    mean  std  median
# Month
# 1                        32.243898  16.000454  33.250  2020.0  0.0  2020.0
# 2                        26.817241  18.869329  27.405  2020.0  0.0  2020.0
# 3                        23.894778  14.118996  24.530  2020.0  0.0  2020.0
# 4                        20.556000  19.128350  21.865  2020.0  0.0  2020.0
# 5                        20.828374  18.428701  22.015  2020.0  0.0  2020.0
# 6                        28.469792  11.458019  30.020  2020.0  0.0  2020.0
# 7                        32.456626  11.137667  32.160  2020.0  0.0  2020.0
# 8                        34.884220  13.866203  33.455  2020.0  0.0  2020.0
# 9                        41.457958  21.240770  39.615  2020.0  0.0  2020.0
# 10                       34.587369  15.668929  34.130  2020.0  0.0  2020.0
# 11                       35.908306  16.169875  36.090  2020.0  0.0  2020.0
# 12                       33.439395  17.715261  35.620  2020.0  0.0  2020.0
#
#              Day
#             mean       std median
# Month
# 1      16.000000  8.950289   16.0
# 2      15.000000  8.372617   15.0
# 3      15.982503  8.943577   16.0
# 4      15.500000  8.661458   15.5
# 5      16.000000  8.950289   16.0
# 6      15.500000  8.661458   15.5
# 7      16.000000  8.950289   16.0
# 8      16.000000  8.950289   16.0
# 9      15.500000  8.661458   15.5
# 10     16.012081  8.950348   16.0
# 11     15.500000  8.661458   15.5
# 12     16.000000  8.950289   16.0

# %%
new_df=group_month.agg(func=['mean', 'std', 'median']).loc[:,group_month.agg(func=['mean', 'std', 'median']).columns[:-6]]
new_df
# Out:
#       Deutschland/Luxemburg[€/MWh]
#                               mean        std  median
# Month
# 1                        32.243898  16.000454  33.250
# 2                        26.817241  18.869329  27.405
# 3                        23.894778  14.118996  24.530
# 4                        20.556000  19.128350  21.865
# 5                        20.828374  18.428701  22.015
# 6                        28.469792  11.458019  30.020
# 7                        32.456626  11.137667  32.160
# 8                        34.884220  13.866203  33.455
# 9                        41.457958  21.240770  39.615
# 10                       34.587369  15.668929  34.130
# 11                       35.908306  16.169875  36.090
# 12                       33.439395  17.715261  35.620

# %%
sns.pairplot(df)

# %%
months = df['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month.mean()['Month'], group_month.mean()['Deutschland/Luxemburg[€/MWh]'],'r-o')
plt.title(" German Price v/s month for the year 2020")
plt.ylabel("Deutschland/Luxemburg[€/MWh]")
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)

plt.savefig("Price of year 2020")

# %% [markdown]
# ---

# %%
forca_df_2020 = pd.read_excel("/content/Prognostizierte_Erzeugung_202001010000_202012312359.xlsx")
forca_df_2020
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#              Datenkategorie: Prognostizierte Erzeugung Unnamed: 1 Unnamed: 2  \
# 0                                           Region: DE        NaN        NaN
# 1      Zeitraum: 01.01.2020, 00:00 - 31.12.2020, 23:59        NaN        NaN
# 2                             Stand: 04.05.2022, 15:45        NaN        NaN
# 3                     (c) Bundesnetzagentur | SMARD.de        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ...                                                ...        ...        ...
# 35137                                       31.12.2020      22:45          -
# 35138                                       31.12.2020      23:00    38265.0
# 35139                                       31.12.2020      23:15          -
# 35140                                       31.12.2020      23:30          -
# 35141                                       31.12.2020      23:45          -
#
#       Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0            NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN
# 3            NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...
# 35137      140.0     1525.0        0.0          -
# 35138      137.0     1494.0        0.0    31870.0
# 35139      135.0     1474.0        0.0          -
# 35140      135.0     1454.0        0.0          -
# 35141      134.0     1434.0        0.0          -
#
# [35142 rows x 7 columns]

# %%
forca_df_2020=forca_df_2020.dropna(axis=0)

# %%
forca_df_2020=forca_df_2020.rename(columns={"Datenkategorie: Prognostizierte Erzeugung":"Date","Unnamed: 1":"Time","Unnamed: 2":"Total","Unnamed: 3":"Wind Offshore[MWh]","Unnamed: 4":"Wind Onshore[MWh]","Unnamed: 5":"Photovoltaik[MWh]","Unnamed: 6":"Sonstige[MWh]"})
forca_df_2020
# Out:
#              Date     Time        Total  Wind Offshore[MWh]  \
# 5           Datum  Uhrzeit  Gesamt[MWh]  Wind Offshore[MWh]
# 6      01.01.2020    00:00      41731.0               161.0
# 7      01.01.2020    00:15            -               174.0
# 8      01.01.2020    00:30            -               188.0
# 9      01.01.2020    00:45            -               201.0
# ...           ...      ...          ...                 ...
# 35137  31.12.2020    22:45            -               140.0
# 35138  31.12.2020    23:00      38265.0               137.0
# 35139  31.12.2020    23:15            -               135.0
# 35140  31.12.2020    23:30            -               135.0
# 35141  31.12.2020    23:45            -               134.0
#
#        Wind Onshore[MWh]  Photovoltaik[MWh]  Sonstige[MWh]
# 5      Wind Onshore[MWh]  Photovoltaik[MWh]  Sonstige[MWh]
# 6                 1436.0                0.0        35227.0
# 7                 1442.0                0.0              -
# 8                 1449.0                0.0              -
# 9                 1455.0                0.0              -
# ...                  ...                ...            ...
# 35137             1525.0                0.0              -
# 35138             1494.0                0.0        31870.0
# 35139             1474.0                0.0              -
# 35140             1454.0                0.0              -
# 35141             1434.0                0.0              -
#
# [35137 rows x 7 columns]

# %%
forca_df_2020=forca_df_2020.drop(5,axis=0)

# %%
forca_df_2020
# Out:
#              Date   Time    Total Wind Offshore[MWh] Wind Onshore[MWh]  \
# 6      01.01.2020  00:00  41731.0              161.0            1436.0
# 7      01.01.2020  00:15        -              174.0            1442.0
# 8      01.01.2020  00:30        -              188.0            1449.0
# 9      01.01.2020  00:45        -              201.0            1455.0
# 10     01.01.2020  01:00  42861.0              218.0            1462.0
# ...           ...    ...      ...                ...               ...
# 35137  31.12.2020  22:45        -              140.0            1525.0
# 35138  31.12.2020  23:00  38265.0              137.0            1494.0
# 35139  31.12.2020  23:15        -              135.0            1474.0
# 35140  31.12.2020  23:30        -              135.0            1454.0
# 35141  31.12.2020  23:45        -              134.0            1434.0
#
#       Photovoltaik[MWh] Sonstige[MWh]
# 6                   0.0       35227.0
# 7                   0.0             -
# 8                   0.0             -
# 9                   0.0             -
# 10                  0.0       35964.0
# ...                 ...           ...
# 35137               0.0             -
# 35138               0.0       31870.0
# 35139               0.0             -
# 35140               0.0             -
# 35141               0.0             -
#
# [35136 rows x 7 columns]

# %%
forca_df_2020.isnull().sum()
# Out:
# Date                  0
# Time                  0
# Total                 0
# Wind Offshore[MWh]    0
# Wind Onshore[MWh]     0
# Photovoltaik[MWh]     0
# Sonstige[MWh]         0
# dtype: int64

# %%
sns.pairplot(forca_df_2020)

# %%
forca_df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35136 entries, 6 to 35141
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                35136 non-null  object
#  1   Time                35136 non-null  object
#  2   Total               35136 non-null  object
#  3   Wind Offshore[MWh]  35136 non-null  object
#  4   Wind Onshore[MWh]   35136 non-null  object
#  5   Photovoltaik[MWh]   35136 non-null  object
#  6   Sonstige[MWh]       35136 non-null  object
# dtypes: object(7)
# memory usage: 2.1+ MB

# %%
sns.distplot(forca_df_2020['Wind Offshore[MWh]'])
#plt.savefig("Distributionplot for german price data ")

# %%
import missingno as msno
msno.bar(forca_df_2020)
plt.savefig("missing value for price german")
plt.savefig("missing value fro the predicted data german")

# %%
forca_df_2020 = forca_df_2020.replace(["-"],0)
forca_df_2020

# %%
forca_df_2020["Total"]=forca_df_2020["Total"].astype(float)

# %%
forca_df_2020["Wind Offshore[MWh]"]=forca_df_2020["Wind Offshore[MWh]"].astype(float)
forca_df_2020["Wind Onshore[MWh]"]=forca_df_2020["Wind Onshore[MWh]"].astype(float)
forca_df_2020["Photovoltaik[MWh]"]=forca_df_2020["Photovoltaik[MWh]"].astype(float)
forca_df_2020["Sonstige[MWh]"]=forca_df_2020["Sonstige[MWh]"].astype(float)

# %%
forca_df_2020.info()

# %%
dt_series_1 = forca_df_2020['Date'] + ' ' + pd.Series(data=[str(item).replace(".", ":") for item in forca_df_2020['Time']], index=forca_df_2020.index)
dt_series_1 = pd.to_datetime(dt_series_1)
dt_series_1

# %%
df_1 = forca_df_2020.drop(columns=['Date', 'Time'], axis=1)
df_1.insert(loc=0, column='DateTime', value=dt_series_1)
df_1

# %%
year_series = dt_series_1.dt.year
month_series = dt_series_1.dt.month
day_series = dt_series_1.dt.day
day_name_series = dt_series_1.dt.day_name()

# %%
df_1['Year'] = year_series
df_1['Month'] = month_series
df_1['Day'] = day_series
df_1['Day Name'] = day_name_series

# %%
df_1 = df_1.sort_values(by='DateTime')
df_1

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df_1["Month"],df_1["Wind Offshore[MWh]"])

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df_1["Month"],df_1["Photovoltaik[MWh]"])

# %%
group_month_1 = df_1.groupby(by='Month',as_index = False)
group_month_1

# %%
group_month_1.describe()

# %%
group_month_1.agg(func=['mean', 'std', 'median'])

# %%
months = df_1['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_1.mean()['Month'], group_month_1.mean()['Total'],'r-o')
#plt.plot(group_month_1.mean()['Month'], group_month.mean()['Deutschland/Luxemburg[€/MWh]'],'g-o')
plt.title("forecast generation v/s month for the year 2020")
plt.ylabel("total")
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
# create figure and axis objects with subplots()
months = df_1['DateTime'].dt.month_name().unique()
fig=plt.figure(figsize=(15, 5))
ax = fig.subplots()
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)
# make a plot
ax.plot(group_month_1.mean()['Month'], group_month_1.mean()['Total'],'r-o')
# set x-axis label
ax.set_xlabel("months",fontsize=14)
# set y-axis label
ax.set_ylabel("total forecast",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(group_month_1.mean()['Month'], group_month.mean()['Deutschland/Luxemburg[€/MWh]'],'g-o')
ax2.set_ylabel("price",color="green",fontsize=14)

plt.show()

# %%
months = df_1['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_1.mean()['Month'], group_month_1.mean()['Photovoltaik[MWh]'],'r-o')
#plt.plot(group_month_1.mean()['Month'], group_month.mean()['Deutschland/Luxemburg[€/MWh]'],'g-o')
plt.title("forecast generation of solar v/s month for the year 2020")
plt.ylabel("total")
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
months = df_1['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_1.mean()['Month'], group_month_1.mean()['Wind Offshore[MWh]'],'r-o')
plt.plot(group_month_1.mean()['Month'], group_month_1.mean()['Wind Onshore[MWh]'],'g-o')
plt.title("forecast generation of wind energy v/s month for the year 2020")
plt.ylabel("total")
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
months = df_1['DateTime'].dt.month_name().unique()
fig=plt.figure(figsize=(15, 5))
ax = fig.subplots()
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)
# make a plot
ax.plot(group_month_1.mean()['Month'], group_month_1.mean()['Total'],'r-o')
plt.plot(group_month_1.mean()['Month'], group_month_1.mean()['Photovoltaik[MWh]'],'b-o')
plt.plot(group_month_1.mean()['Month'], group_month_1.mean()['Wind Offshore[MWh]'],color="black",marker="o")
plt.plot(group_month_1.mean()['Month'], group_month_1.mean()['Wind Onshore[MWh]'],color="yellow",marker="o")
# set x-axis label
ax.set_xlabel("months",fontsize=14)
# set y-axis label
ax.set_ylabel("total forecast",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(group_month_1.mean()['Month'], group_month.mean()['Deutschland/Luxemburg[€/MWh]'],'g-o')
ax2.set_ylabel("price",color="green",fontsize=14)

plt.show()

# %%
hour_series = dt_series_1.dt.hour
min_series = dt_series_1.dt.minute
sec_series = dt_series_1.dt.second

# %%
df_1['Hours'] = hour_series
df_1['minutes'] = min_series
df_1['seconds'] = sec_series

# %%
df_1

# %%
estimate_solar_germany=df_1.pivot_table(index=['Hours'], columns=['Year', 'Month'], values='Sonstige[MWh]')
#estimate_solar_germany

# %%
fig, axes = plt.subplots(figsize=(20, 15), sharex=True)
start, end = axes.get_ylim()

axes = sns.heatmap(estimate_solar_germany)

#axes.set_title("Heatmap for Germany's power grid frequency(mHz) from {} to {}.".format(min(years), max(years), fontsize=60))
#_ = axes.set_yticks(np.arange(0, 86400, 3600))
# = axes.set_yticklabels(range(0, 24, 1))
#_ = axes.set_ylabel('Hours')
# = axes.set_xlabel('Date')

# %%
estimate_wind_germany=df_1.pivot_table(index=['Hours'], columns=['Year', 'Month'], values=[	'Wind Offshore[MWh]','Wind Onshore[MWh]'])

# %%
fig, axes = plt.subplots(figsize=(20, 15), sharex=True)
start, end = axes.get_ylim()

axes = sns.heatmap(estimate_wind_germany)

# %%
estimate_total_germany=df_1.pivot_table(index=['Hours'], columns=['Year', 'Month'], values="Total")

# %%
fig, axes = plt.subplots(figsize=(20, 15), sharex=True)
start, end = axes.get_ylim()

axes = sns.heatmap(estimate_total_germany)
#ax2.plot(group_month_1.mean()['Month'], group_month.mean()['Deutschland/Luxemburg[€/MWh]'],'g-o')

# %%
forca_df_2020.corr()
# Out:
#                        Total  Wind Offshore[MWh]  Wind Onshore[MWh]  \
# Total               1.000000            0.052209           0.067524
# Wind Offshore[MWh]  0.052209            1.000000           0.724142
# Wind Onshore[MWh]   0.067524            0.724142           1.000000
# Photovoltaik[MWh]   0.066293           -0.191858          -0.207771
# Sonstige[MWh]       0.968210           -0.024424          -0.027593
#
#                     Photovoltaik[MWh]  Sonstige[MWh]
# Total                        0.066293       0.968210
# Wind Offshore[MWh]          -0.191858      -0.024424
# Wind Onshore[MWh]           -0.207771      -0.027593
# Photovoltaik[MWh]            1.000000       0.018158
# Sonstige[MWh]                0.018158       1.000000

# %%
df
# Out:
#                 DateTime  Deutschland/Luxemburg[€/MWh]  Year  Month  Day  \
# 6    2020-01-01 00:00:00                         41.88  2020      1    1
# 7    2020-01-01 01:00:00                         38.60  2020      1    1
# 8    2020-01-01 02:00:00                         36.55  2020      1    1
# 9    2020-01-01 03:00:00                         32.32  2020      1    1
# 10   2020-01-01 04:00:00                         30.85  2020      1    1
# ...                  ...                           ...   ...    ...  ...
# 8785 2020-12-31 19:00:00                         59.47  2020     12   31
# 8786 2020-12-31 20:00:00                         56.70  2020     12   31
# 8787 2020-12-31 21:00:00                         52.44  2020     12   31
# 8788 2020-12-31 22:00:00                         51.86  2020     12   31
# 8789 2020-12-31 23:00:00                         52.26  2020     12   31
#
#        Day Name
# 6     Wednesday
# 7     Wednesday
# 8     Wednesday
# 9     Wednesday
# 10    Wednesday
# ...         ...
# 8785   Thursday
# 8786   Thursday
# 8787   Thursday
# 8788   Thursday
# 8789   Thursday
#
# [8784 rows x 6 columns]

# %%
forca_df_2020_with = forca_df_2020

# %%
forca_df_2020_with["price"] = df["Deutschland/Luxemburg[€/MWh]"]

# %%
forca_df_2020_with.isnull().sum()
# Out:
# Date                      0
# Time                      0
# Total                     0
# Wind Offshore[MWh]        0
# Wind Onshore[MWh]         0
# Photovoltaik[MWh]         0
# Sonstige[MWh]             0
# price                 26352
# dtype: int64

# %%
df['DateTime']
# Out:
# 6      2020-01-01 00:00:00
# 7      2020-01-01 01:00:00
# 8      2020-01-01 02:00:00
# 9      2020-01-01 03:00:00
# 10     2020-01-01 04:00:00
#                ...
# 8785   2020-12-31 19:00:00
# 8786   2020-12-31 20:00:00
# 8787   2020-12-31 21:00:00
# 8788   2020-12-31 22:00:00
# 8789   2020-12-31 23:00:00
# Name: DateTime, Length: 8784, dtype: datetime64[ns]

# %%
forca_df_2020['Date']
# Out:
# 6        01.01.2020
# 7        01.01.2020
# 8        01.01.2020
# 9        01.01.2020
# 10       01.01.2020
#             ...
# 35137    31.12.2020
# 35138    31.12.2020
# 35139    31.12.2020
# 35140    31.12.2020
# 35141    31.12.2020
# Name: Date, Length: 35136, dtype: object

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(data=forca_df_2020_with.corr(),annot = True)
plt.title("Pearson Correlation to check interdependence of feature")
plt.savefig("correlation ")

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(data=forca_df_2020.corr(),annot = True)
plt.savefig("correlation of ")

# %%
plt.hist2d(group_month_1.mean()['Wind Offshore[MWh]'], group_month_1.mean()['Wind Onshore[MWh]'], bins=(50, 50), vmax=1)
plt.colorbar()
#plt.xlabel('Wind Direction [deg]')
#plt.ylabel('Wind Velocity [m/s]')

# %%
price_df_2020 = pd.read_excel("/content/Gro_handelspreise_202001010000_202012312359.xlsx")
price_df_2020.head(7)
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                  Datenkategorie: Großhandelspreise Unnamed: 1  \
# 0                                       Region: DE        NaN
# 1  Zeitraum: 01.01.2020, 00:00 - 31.12.2020, 23:59        NaN
# 2                         Stand: 04.05.2022, 00:53        NaN
# 3                 (c) Bundesnetzagentur | SMARD.de        NaN
# 4                                              NaN        NaN
# 5                                            Datum    Uhrzeit
# 6                                       01.01.2020      00:00
#
#                      Unnamed: 2         Unnamed: 3         Unnamed: 4  \
# 0                           NaN                NaN                NaN
# 1                           NaN                NaN                NaN
# 2                           NaN                NaN                NaN
# 3                           NaN                NaN                NaN
# 4                           NaN                NaN                NaN
# 5  Deutschland/Luxemburg[€/MWh]  Dänemark 1[€/MWh]  Dänemark 2[€/MWh]
# 6                         41.88              33.42              33.42
#
#           Unnamed: 5             Unnamed: 6          Unnamed: 7    Unnamed: 8  \
# 0                NaN                    NaN                 NaN           NaN
# 1                NaN                    NaN                 NaN           NaN
# 2                NaN                    NaN                 NaN           NaN
# 3                NaN                    NaN                 NaN           NaN
# 4                NaN                    NaN                 NaN           NaN
# 5  Frankreich[€/MWh]  Italien (Nord)[€/MWh]  Niederlande[€/MWh]  Polen[€/MWh]
# 6              41.88                  41.88               41.88         34.95
#
#           Unnamed: 9     Unnamed: 10       Unnamed: 11        Unnamed: 12  \
# 0                NaN             NaN               NaN                NaN
# 1                NaN             NaN               NaN                NaN
# 2                NaN             NaN               NaN                NaN
# 3                NaN             NaN               NaN                NaN
# 4                NaN             NaN               NaN                NaN
# 5  Schweden 4[€/MWh]  Schweiz[€/MWh]  Slowenien[€/MWh]  Tschechien[€/MWh]
# 6              28.78           35.42             41.88               33.2
#
#      Unnamed: 13        Unnamed: 14      Unnamed: 15     Unnamed: 16  \
# 0            NaN                NaN              NaN             NaN
# 1            NaN                NaN              NaN             NaN
# 2            NaN                NaN              NaN             NaN
# 3            NaN                NaN              NaN             NaN
# 4            NaN                NaN              NaN             NaN
# 5  Ungarn[€/MWh]  Österreich[€/MWh]  DE/AT/LU[€/MWh]  Belgien[€/MWh]
# 6          33.55              41.88                -           41.88
#
#          Unnamed: 17
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5  Norwegen 2[€/MWh]
# 6              31.82

# %%
price_df_2020_norway = price_df_2020[['Datenkategorie: Großhandelspreise','Unnamed: 1','Unnamed: 17']]
price_df_2020_norway.head(6)
# Out:
#                  Datenkategorie: Großhandelspreise Unnamed: 1  \
# 0                                       Region: DE        NaN
# 1  Zeitraum: 01.01.2020, 00:00 - 31.12.2020, 23:59        NaN
# 2                         Stand: 04.05.2022, 00:53        NaN
# 3                 (c) Bundesnetzagentur | SMARD.de        NaN
# 4                                              NaN        NaN
# 5                                            Datum    Uhrzeit
#
#          Unnamed: 17
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5  Norwegen 2[€/MWh]

# %%
price_df_2020_norway=price_df_2020_norway.rename(columns={'Datenkategorie: Großhandelspreise':"Date","Unnamed: 1":"Time","Unnamed: 17":"Norwegen 2[€/MWh]"})
price_df_2020_norway = price_df_2020_norway.iloc[6:]
price_df_2020_norway.head()
# Out:
#           Date   Time Norwegen 2[€/MWh]
# 6   01.01.2020  00:00             31.82
# 7   01.01.2020  01:00             31.77
# 8   01.01.2020  02:00             31.57
# 9   01.01.2020  03:00             31.28
# 10  01.01.2020  04:00             30.72

# %%
price_df_2020_norway.isnull().sum()
# Out:
# Date                 0
# Time                 0
# Norwegen 2[€/MWh]    0
# dtype: int64

# %%
price_df_2020_norway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 6 to 8789
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               8784 non-null   object
#  1   Time               8784 non-null   object
#  2   Norwegen 2[€/MWh]  8784 non-null   object
# dtypes: object(3)
# memory usage: 206.0+ KB

# %%
price_df_2020_norway["Norwegen 2[€/MWh]"] = price_df_2020_norway["Norwegen 2[€/MWh]"].astype(float)

# %%
price_df_2020_norway.describe()
# Out:
#        Norwegen 2[€/MWh]
# count        8784.000000
# mean            9.291152
# std             8.261798
# min            -1.730000
# 25%             2.130000
# 50%             6.950000
# 75%            13.552500
# max            99.920000

# %%
price_df_2020_norway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 6 to 8789
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               8784 non-null   object
#  1   Time               8784 non-null   object
#  2   Norwegen 2[€/MWh]  8784 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 206.0+ KB

# %%
dt_series_norway = price_df_2020_norway['Date'] + ' ' + pd.Series(data=[str(item).replace(".", ":") for item in price_df_2020_norway['Time']], index=price_df_2020_norway.index)
dt_series_norway = pd.to_datetime(dt_series)
dt_series_norway
# Out:
# 6      2020-01-01 00:00:00
# 7      2020-01-01 01:00:00
# 8      2020-01-01 02:00:00
# 9      2020-01-01 03:00:00
# 10     2020-01-01 04:00:00
#                ...
# 8785   2020-12-31 19:00:00
# 8786   2020-12-31 20:00:00
# 8787   2020-12-31 21:00:00
# 8788   2020-12-31 22:00:00
# 8789   2020-12-31 23:00:00
# Length: 8784, dtype: datetime64[ns]

# %%
df_norway = price_df_2020_norway.drop(columns=['Date', 'Time'], axis=1)
df_norway.insert(loc=0, column='DateTime', value=dt_series_norway)
df_norway
# Out:
#                 DateTime  Norwegen 2[€/MWh]
# 6    2020-01-01 00:00:00              31.82
# 7    2020-01-01 01:00:00              31.77
# 8    2020-01-01 02:00:00              31.57
# 9    2020-01-01 03:00:00              31.28
# 10   2020-01-01 04:00:00              30.72
# ...                  ...                ...
# 8785 2020-12-31 19:00:00              25.72
# 8786 2020-12-31 20:00:00              24.84
# 8787 2020-12-31 21:00:00              24.77
# 8788 2020-12-31 22:00:00              24.61
# 8789 2020-12-31 23:00:00              24.07
#
# [8784 rows x 2 columns]

# %%
plt.figure(figsize=(10,8))
plt.scatter(df_norway["DateTime"],df_norway["Norwegen 2[€/MWh]"])

# %%
sns.distplot(df_norway['Norwegen 2[€/MWh]'])
plt.savefig("Distributionplot for norway price data ")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
year_series = dt_series_norway.dt.year
month_series = dt_series_norway.dt.month
day_series = dt_series_norway.dt.day  
day_name_series = dt_series_norway.dt.day_name()

# %%
df_norway['Year'] = year_series
df_norway['Month'] = month_series
df_norway['Day'] = day_series
df_norway['Day Name'] = day_name_series

# %%
df_norway = df_norway.sort_values(by='DateTime')
df_norway
# Out:
#                 DateTime  Norwegen 2[€/MWh]  Year  Month  Day   Day Name
# 6    2020-01-01 00:00:00              31.82  2020      1    1  Wednesday
# 7    2020-01-01 01:00:00              31.77  2020      1    1  Wednesday
# 8    2020-01-01 02:00:00              31.57  2020      1    1  Wednesday
# 9    2020-01-01 03:00:00              31.28  2020      1    1  Wednesday
# 10   2020-01-01 04:00:00              30.72  2020      1    1  Wednesday
# ...                  ...                ...   ...    ...  ...        ...
# 8785 2020-12-31 19:00:00              25.72  2020     12   31   Thursday
# 8786 2020-12-31 20:00:00              24.84  2020     12   31   Thursday
# 8787 2020-12-31 21:00:00              24.77  2020     12   31   Thursday
# 8788 2020-12-31 22:00:00              24.61  2020     12   31   Thursday
# 8789 2020-12-31 23:00:00              24.07  2020     12   31   Thursday
#
# [8784 rows x 6 columns]

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df_norway["Month"],df_norway["Norwegen 2[€/MWh]"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
group_month_norway = df_norway.groupby(by='Month',as_index = False)
group_month_norway

# %%
group_month_norway.describe()
# Out:
#    Norwegen 2[€/MWh]                                                       \
#                count       mean        std   min     25%     50%      75%
# 0              744.0  17.156142   8.510408  0.46  9.8525  20.425  22.7625
# 1              696.0   9.929713   5.889182 -1.73  7.0875   9.825  11.5025
# 2              743.0   7.912961   5.675407  0.20  5.5100   6.980   8.1500
# 3              720.0   6.751069   5.975858  0.94  4.5175   4.960   5.4925
# 4              744.0   8.069960   6.784248  0.34  2.1300   6.750  12.5025
# 5              720.0   4.678819   6.789035 -0.09  1.3100   1.450   5.4650
# 6              744.0   4.537231   6.381303  0.07  1.4700   1.550   4.5250
# 7              744.0   6.955806   5.766980  1.01  3.2900   4.635   9.3275
# 8              720.0   8.272292   8.060386  1.35  3.1300   6.915  11.2050
# 9              745.0  14.527248  10.479115  1.49  9.2900  12.990  19.1800
# 10             720.0   6.552681   6.531663  0.02  1.5500   3.510  11.1650
# 11             744.0  15.830282   7.569502  0.67  9.9575  18.185  22.1625
#
#             Year          ... Month          Day                            \
#       max  count    mean  ...   75%   max  count       mean       std  min
# 0   31.82  744.0  2020.0  ...   1.0   1.0  744.0  16.000000  8.950289  1.0
# 1   31.83  696.0  2020.0  ...   2.0   2.0  696.0  15.000000  8.372617  1.0
# 2   30.48  743.0  2020.0  ...   3.0   3.0  743.0  15.982503  8.943577  1.0
# 3   30.83  720.0  2020.0  ...   4.0   4.0  720.0  15.500000  8.661458  1.0
# 4   32.04  744.0  2020.0  ...   5.0   5.0  744.0  16.000000  8.950289  1.0
# 5   31.76  720.0  2020.0  ...   6.0   6.0  720.0  15.500000  8.661458  1.0
# 6   31.15  744.0  2020.0  ...   7.0   7.0  744.0  16.000000  8.950289  1.0
# 7   29.02  744.0  2020.0  ...   8.0   8.0  744.0  16.000000  8.950289  1.0
# 8   99.92  720.0  2020.0  ...   9.0   9.0  720.0  15.500000  8.661458  1.0
# 9   93.34  745.0  2020.0  ...  10.0  10.0  745.0  16.012081  8.950348  1.0
# 10  26.53  720.0  2020.0  ...  11.0  11.0  720.0  15.500000  8.661458  1.0
# 11  31.58  744.0  2020.0  ...  12.0  12.0  744.0  16.000000  8.950289  1.0
#
#
#     25%   50%   75%   max
# 0   8.0  16.0  24.0  31.0
# 1   8.0  15.0  22.0  29.0
# 2   8.0  16.0  24.0  31.0
# 3   8.0  15.5  23.0  30.0
# 4   8.0  16.0  24.0  31.0
# 5   8.0  15.5  23.0  30.0
# 6   8.0  16.0  24.0  31.0
# 7   8.0  16.0  24.0  31.0
# 8   8.0  15.5  23.0  30.0
# 9   8.0  16.0  24.0  31.0
# 10  8.0  15.5  23.0  30.0
# 11  8.0  16.0  24.0  31.0
#
# [12 rows x 32 columns]

# %%
group_month_norway.agg(func=['mean', 'std', 'median'])
# Out:
#       Norwegen 2[€/MWh]                       Year                     Day  \
#                    mean        std  median    mean  std  median       mean
# Month
# 1             17.156142   8.510408  20.425  2020.0  0.0  2020.0  16.000000
# 2              9.929713   5.889182   9.825  2020.0  0.0  2020.0  15.000000
# 3              7.912961   5.675407   6.980  2020.0  0.0  2020.0  15.982503
# 4              6.751069   5.975858   4.960  2020.0  0.0  2020.0  15.500000
# 5              8.069960   6.784248   6.750  2020.0  0.0  2020.0  16.000000
# 6              4.678819   6.789035   1.450  2020.0  0.0  2020.0  15.500000
# 7              4.537231   6.381303   1.550  2020.0  0.0  2020.0  16.000000
# 8              6.955806   5.766980   4.635  2020.0  0.0  2020.0  16.000000
# 9              8.272292   8.060386   6.915  2020.0  0.0  2020.0  15.500000
# 10            14.527248  10.479115  12.990  2020.0  0.0  2020.0  16.012081
# 11             6.552681   6.531663   3.510  2020.0  0.0  2020.0  15.500000
# 12            15.830282   7.569502  18.185  2020.0  0.0  2020.0  16.000000
#
#
#             std median
# Month
# 1      8.950289   16.0
# 2      8.372617   15.0
# 3      8.943577   16.0
# 4      8.661458   15.5
# 5      8.950289   16.0
# 6      8.661458   15.5
# 7      8.950289   16.0
# 8      8.950289   16.0
# 9      8.661458   15.5
# 10     8.950348   16.0
# 11     8.661458   15.5
# 12     8.950289   16.0

# %%
new_df_norway=group_month_norway.agg(func=['mean', 'std', 'median']).loc[:,group_month_norway.agg(func=['mean', 'std', 'median']).columns[:-6]]
new_df_norway
# Out:
#       Norwegen 2[€/MWh]
#                    mean        std  median
# Month
# 1             17.156142   8.510408  20.425
# 2              9.929713   5.889182   9.825
# 3              7.912961   5.675407   6.980
# 4              6.751069   5.975858   4.960
# 5              8.069960   6.784248   6.750
# 6              4.678819   6.789035   1.450
# 7              4.537231   6.381303   1.550
# 8              6.955806   5.766980   4.635
# 9              8.272292   8.060386   6.915
# 10            14.527248  10.479115  12.990
# 11             6.552681   6.531663   3.510
# 12            15.830282   7.569502  18.185

# %%
months = df['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_norway.mean()['Month'], group_month_norway.mean()['Norwegen 2[€/MWh]'],'r-o')
plt.plot(group_month.mean()['Month'], group_month.mean()['Deutschland/Luxemburg[€/MWh]'],'g-o') #for comparison of both germany and norway 
plt.title("Price v/s month for the year 2020")
plt.ylabel("Norwegen 2[€/MWh]")
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
forca_df_norway = pd.read_excel("/content/data of generation of norway.xlsx")
forca_df_norway
# Out:
#     country_or_region       date          variable  generation_twh
# 0              Norway 2015-01-01         Bioenergy            0.00
# 1              Norway 2015-01-01             Clean           14.50
# 2              Norway 2015-01-01              Coal            0.00
# 3              Norway 2015-01-01            Fossil            0.28
# 4              Norway 2015-01-01               Gas            0.26
# ..                ...        ...               ...             ...
# 974            Norway 2022-05-01           Nuclear            0.00
# 975            Norway 2022-05-01      Other Fossil            0.02
# 976            Norway 2022-05-01  Other Renewables            0.04
# 977            Norway 2022-05-01             Solar            0.00
# 978            Norway 2022-05-01              Wind            1.14
#
# [979 rows x 4 columns]

# %%
forca_df_norway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country_or_region  979 non-null    object
#  1   date               979 non-null    datetime64[ns]
#  2   variable           979 non-null    object
#  3   generation_twh     979 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 30.7+ KB

# %%
forca_df_norway['date'] = pd.to_datetime(forca_df_norway['date']) 
start_date ='2020-01-01'
end_date = '2020-12-31'
mask = (forca_df_norway["date"] >= start_date) & (forca_df_norway["date"]<=end_date )
forca_df_norway=forca_df_norway.loc[mask]

# %%
forca_df_norway
# Out:
#     country_or_region       date          variable  generation_twh
# 660            Norway 2020-01-01         Bioenergy            0.00
# 661            Norway 2020-01-01             Clean           12.95
# 662            Norway 2020-01-01              Coal            0.00
# 663            Norway 2020-01-01            Fossil            0.30
# 664            Norway 2020-01-01               Gas            0.27
# ..                ...        ...               ...             ...
# 787            Norway 2020-12-01           Nuclear            0.00
# 788            Norway 2020-12-01      Other Fossil            0.02
# 789            Norway 2020-12-01  Other Renewables            0.02
# 790            Norway 2020-12-01             Solar            0.00
# 791            Norway 2020-12-01              Wind            1.22
#
# [132 rows x 4 columns]

# %%
for i in forca_df_norway["variable"]:
  print(i)
# Out:
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind
# Bioenergy
# Clean
# Coal
# Fossil
# Gas
# Hydro
# Nuclear
# Other Fossil
# Other Renewables
# Solar
# Wind

# %%
forca_df_norway
# Out:
#     country_or_region       date          variable  generation_twh
# 660            Norway 2020-01-01         Bioenergy            0.00
# 661            Norway 2020-01-01             Clean           12.95
# 662            Norway 2020-01-01              Coal            0.00
# 663            Norway 2020-01-01            Fossil            0.30
# 664            Norway 2020-01-01               Gas            0.27
# ..                ...        ...               ...             ...
# 787            Norway 2020-12-01           Nuclear            0.00
# 788            Norway 2020-12-01      Other Fossil            0.02
# 789            Norway 2020-12-01  Other Renewables            0.02
# 790            Norway 2020-12-01             Solar            0.00
# 791            Norway 2020-12-01              Wind            1.22
#
# [132 rows x 4 columns]

# %%
forca_df_norway =forca_df_norway.loc[forca_df_norway['variable'].isin(['Solar','Wind'])]
forca_df_norway
# Out:
#     country_or_region       date variable  generation_twh
# 669            Norway 2020-01-01    Solar            0.00
# 670            Norway 2020-01-01     Wind            0.99
# 680            Norway 2020-02-01    Solar            0.00
# 681            Norway 2020-02-01     Wind            0.81
# 691            Norway 2020-03-01    Solar            0.00
# 692            Norway 2020-03-01     Wind            0.90
# 702            Norway 2020-04-01    Solar            0.00
# 703            Norway 2020-04-01     Wind            0.65
# 713            Norway 2020-05-01    Solar            0.00
# 714            Norway 2020-05-01     Wind            0.57
# 724            Norway 2020-06-01    Solar            0.00
# 725            Norway 2020-06-01     Wind            0.39
# 735            Norway 2020-07-01    Solar            0.00
# 736            Norway 2020-07-01     Wind            0.49
# 746            Norway 2020-08-01    Solar            0.00
# 747            Norway 2020-08-01     Wind            0.43
# 757            Norway 2020-09-01    Solar            0.00
# 758            Norway 2020-09-01     Wind            0.80
# 768            Norway 2020-10-01    Solar            0.00
# 769            Norway 2020-10-01     Wind            0.83
# 779            Norway 2020-11-01    Solar            0.00
# 780            Norway 2020-11-01     Wind            1.19
# 790            Norway 2020-12-01    Solar            0.00
# 791            Norway 2020-12-01     Wind            1.22

# %%
import missingno as msno
msno.bar(forca_df_norway)
plt.savefig("missing value for price german")
plt.savefig("missing value fro the predicted data norway")

# %%
forca_norway_solar = forca_df_norway.loc[forca_df_norway['variable'].isin(['Solar'])]
forca_norway_solar
# Out:
#     country_or_region       date variable  generation_twh
# 669            Norway 2020-01-01    Solar             0.0
# 680            Norway 2020-02-01    Solar             0.0
# 691            Norway 2020-03-01    Solar             0.0
# 702            Norway 2020-04-01    Solar             0.0
# 713            Norway 2020-05-01    Solar             0.0
# 724            Norway 2020-06-01    Solar             0.0
# 735            Norway 2020-07-01    Solar             0.0
# 746            Norway 2020-08-01    Solar             0.0
# 757            Norway 2020-09-01    Solar             0.0
# 768            Norway 2020-10-01    Solar             0.0
# 779            Norway 2020-11-01    Solar             0.0
# 790            Norway 2020-12-01    Solar             0.0

# %%
forca_norway_wind = forca_df_norway.loc[forca_df_norway['variable'].isin(['Wind'])]
forca_norway_wind
# Out:
#     country_or_region       date variable  generation_twh
# 670            Norway 2020-01-01     Wind            0.99
# 681            Norway 2020-02-01     Wind            0.81
# 692            Norway 2020-03-01     Wind            0.90
# 703            Norway 2020-04-01     Wind            0.65
# 714            Norway 2020-05-01     Wind            0.57
# 725            Norway 2020-06-01     Wind            0.39
# 736            Norway 2020-07-01     Wind            0.49
# 747            Norway 2020-08-01     Wind            0.43
# 758            Norway 2020-09-01     Wind            0.80
# 769            Norway 2020-10-01     Wind            0.83
# 780            Norway 2020-11-01     Wind            1.19
# 791            Norway 2020-12-01     Wind            1.22

# %%
estimate_solar_germany=df_1.pivot_table(index=['Hours'], columns=['Year', 'Month'], values='Sonstige[MWh]')

# %%
plt.figure(figsize=(10,8))
plt.plot(forca_norway_wind["date"],forca_norway_wind["generation_twh"],'g-o')
#plt.plot(forca_norway_wind["date"],forca_norway_solar["generation_twh"],"r-o")

# %%
def terwhatts(x):
  y= x * 1000000
  return y

# %%
forca_norway_wind["generation_twh"]=forca_norway_wind["generation_twh"].apply(terwhatts)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
forca_norway_wind
# Out:
#     country_or_region       date variable  generation_twh
# 670            Norway 2020-01-01     Wind        990000.0
# 681            Norway 2020-02-01     Wind        810000.0
# 692            Norway 2020-03-01     Wind        900000.0
# 703            Norway 2020-04-01     Wind        650000.0
# 714            Norway 2020-05-01     Wind        570000.0
# 725            Norway 2020-06-01     Wind        390000.0
# 736            Norway 2020-07-01     Wind        490000.0
# 747            Norway 2020-08-01     Wind        430000.0
# 758            Norway 2020-09-01     Wind        800000.0
# 769            Norway 2020-10-01     Wind        830000.0
# 780            Norway 2020-11-01     Wind       1190000.0
# 791            Norway 2020-12-01     Wind       1220000.0

# %%
df_1 = df_1.sort_values(by='DateTime')
df_1
# Out:
#                  DateTime    Total  Wind Offshore[MWh]  Wind Onshore[MWh]  \
# 6     2020-01-01 00:00:00  41731.0               161.0             1436.0
# 7     2020-01-01 00:15:00      0.0               174.0             1442.0
# 8     2020-01-01 00:30:00      0.0               188.0             1449.0
# 9     2020-01-01 00:45:00      0.0               201.0             1455.0
# 10    2020-01-01 01:00:00  42861.0               218.0             1462.0
# ...                   ...      ...                 ...                ...
# 35137 2020-12-31 22:45:00      0.0               140.0             1525.0
# 35138 2020-12-31 23:00:00  38265.0               137.0             1494.0
# 35139 2020-12-31 23:15:00      0.0               135.0             1474.0
# 35140 2020-12-31 23:30:00      0.0               135.0             1454.0
# 35141 2020-12-31 23:45:00      0.0               134.0             1434.0
#
#        Photovoltaik[MWh]  Sonstige[MWh]  Year  Month  Day   Day Name  Hours  \
# 6                    0.0        35227.0  2020      1    1  Wednesday      0
# 7                    0.0            0.0  2020      1    1  Wednesday      0
# 8                    0.0            0.0  2020      1    1  Wednesday      0
# 9                    0.0            0.0  2020      1    1  Wednesday      0
# 10                   0.0        35964.0  2020      1    1  Wednesday      1
# ...                  ...            ...   ...    ...  ...        ...    ...
# 35137                0.0            0.0  2020     12   31   Thursday     22
# 35138                0.0        31870.0  2020     12   31   Thursday     23
# 35139                0.0            0.0  2020     12   31   Thursday     23
# 35140                0.0            0.0  2020     12   31   Thursday     23
# 35141                0.0            0.0  2020     12   31   Thursday     23
#
#        minutes  seconds
# 6            0        0
# 7           15        0
# 8           30        0
# 9           45        0
# 10           0        0
# ...        ...      ...
# 35137       45        0
# 35138        0        0
# 35139       15        0
# 35140       30        0
# 35141       45        0
#
# [35136 rows x 13 columns]
