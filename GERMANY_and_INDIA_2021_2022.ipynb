# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/MarketHour.xlsx")
df=df.iloc[4:,:]
df=df.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df =df.rename(columns={df.columns[0]:'Date',df.columns[1]:'Time',df.columns[2]: 'Final Scheduled Volume (MWh)',df.columns[3]:'Solar (MWh)',df.columns[4]:'Non-Solar (MWh)',df.columns[5]:'Hydro (MWh)',df.columns[6]:'MCP (Rs/MWh)',df.columns[7]:'Weighted MCP (Rs/MWh)'})
df.drop([4,5], axis=0, inplace=True)
df
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    27-10-2021  00 - 01                          1.6           0
# 7           NaN  01 - 02                          1.6           0
# 8           NaN  02 - 03                          1.3           0
# 9           NaN  03 - 04                          1.6           0
# 10          NaN  04 - 05                          1.6           0
# ..          ...      ...                          ...         ...
# 144         NaN  Average                       103.35       99.41
# 145  31-10-2021    Total                      5061.69     4441.87
# 146         NaN      Max                       528.80      527.60
# 147         NaN      Min                         1.30        0.00
# 148         NaN  Average                       210.90      185.08
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6               1.6           0      4600.97               4600.97
# ...

# %%
df_1= pd.read_excel("/content/MarketHour (1).xlsx")
df_1=df_1.iloc[4:,:]
df_1=df_1.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df_1 =df_1.rename(columns={df_1.columns[0]:'Date',df_1.columns[1]:'Time',df_1.columns[2]: 'Final Scheduled Volume (MWh)',df_1.columns[3]:'Solar (MWh)',df_1.columns[4]:'Non-Solar (MWh)',df_1.columns[5]:'Hydro (MWh)',df_1.columns[6]:'MCP (Rs/MWh)',df_1.columns[7]:'Weighted MCP (Rs/MWh)'})
df_1.drop([4,5], axis=0, inplace=True)
df_1
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-11-2021  00 - 01                          8.4           0
# 7           NaN  01 - 02                          8.4           0
# 8           NaN  02 - 03                          8.4           0
# 9           NaN  03 - 04                          8.1           0
# 10          NaN  04 - 05                          8.4           0
# ..          ...      ...                          ...         ...
# 844         NaN  Average                       307.38      269.47
# 845  30-11-2021    Total                      5508.68     4521.28
# 846         NaN      Max                      1138.95     1115.35
# 847         NaN      Min                        18.50        0.00
# 848         NaN  Average                       229.53      188.39
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6               8.4           0      4600.79               4600.79
# ...

# %%
df_2= pd.read_excel("/content/MarketHour (2).xlsx")
df_2=df_2.iloc[4:,:]
df_2=df_2.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df_2 =df_2.rename(columns={df_2.columns[0]:'Date',df_2.columns[1]:'Time',df_2.columns[2]: 'Final Scheduled Volume (MWh)',df_2.columns[3]:'Solar (MWh)',df_2.columns[4]:'Non-Solar (MWh)',df_2.columns[5]:'Hydro (MWh)',df_2.columns[6]:'MCP (Rs/MWh)',df_2.columns[7]:'Weighted MCP (Rs/MWh)'})
df_2.drop([4,5], axis=0, inplace=True)
df_2
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-12-2021  00 - 01                       107.75           0
# 7           NaN  01 - 02                       100.75           0
# 8           NaN  02 - 03                        100.5           0
# 9           NaN  03 - 04                        97.75           0
# 10          NaN  04 - 05                        87.25           0
# ..          ...      ...                          ...         ...
# 872         NaN  Average                       149.27       85.29
# 873  31-12-2021    Total                      2987.57     1447.51
# 874         NaN      Max                       441.43      402.73
# 875         NaN      Min                        45.80        0.00
# 876         NaN  Average                       124.48       60.31
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6            107.75           0      4599.69               4599.70
# ...

# %%
df_3= pd.read_excel("/content/MarketHour (3).xlsx")
df_3=df_3.iloc[4:,:]
df_3=df_3.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df_3 =df_3.rename(columns={df_3.columns[0]:'Date',df_3.columns[1]:'Time',df_3.columns[2]: 'Final Scheduled Volume (MWh)',df_3.columns[3]:'Solar (MWh)',df_3.columns[4]:'Non-Solar (MWh)',df_3.columns[5]:'Hydro (MWh)',df_3.columns[6]:'MCP (Rs/MWh)',df_3.columns[7]:'Weighted MCP (Rs/MWh)'})
df_3.drop([4,5], axis=0, inplace=True)
df_3
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-01-2022  00 - 01                          105           0
# 7           NaN  01 - 02                        94.75           0
# 8           NaN  02 - 03                         95.5           0
# 9           NaN  03 - 04                        93.25           0
# 10          NaN  04 - 05                        78.25           0
# ..          ...      ...                          ...         ...
# 872         NaN  Average                       301.00      136.10
# 873  31-01-2022    Total                      6463.88     1644.72
# 874         NaN      Max                       465.45      274.65
# 875         NaN      Min                       191.85        0.00
# 876         NaN  Average                       269.33       68.53
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6               105           0      4599.08               4599.08
# ...

# %%
df_5= pd.read_excel("/content/MarketHour (5).xlsx")
df_5=df_5.iloc[4:,:]
df_5=df_5.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df_5 =df_5.rename(columns={df_5.columns[0]:'Date',df_5.columns[1]:'Time',df_5.columns[2]: 'Final Scheduled Volume (MWh)',df_5.columns[3]:'Solar (MWh)',df_5.columns[4]:'Non-Solar (MWh)',df_5.columns[5]:'Hydro (MWh)',df_5.columns[6]:'MCP (Rs/MWh)',df_5.columns[7]:'Weighted MCP (Rs/MWh)'})
df_5.drop([4,5], axis=0, inplace=True)
df_5
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-02-2022  00 - 01                       177.38           0
# 7           NaN  01 - 02                        176.9           0
# 8           NaN  02 - 03                       177.48           0
# 9           NaN  03 - 04                       177.98           0
# 10          NaN  04 - 05                       176.75           0
# ..          ...      ...                          ...         ...
# 788         NaN  Average                       380.32      127.23
# 789  28-02-2022    Total                      7316.94     1156.53
# 790         NaN      Max                       477.63      222.28
# 791         NaN      Min                       226.35        0.00
# 792         NaN  Average                       304.87       48.19
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6            177.38           0      3826.18               3827.98
# ...

# %%
df_6=pd.read_excel("/content/MarketHour (6).xlsx")
df_6=df_6.iloc[4:,:]
df_6=df_6.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df_6 =df_6.rename(columns={df_6.columns[0]:'Date',df_6.columns[1]:'Time',df_6.columns[2]: 'Final Scheduled Volume (MWh)',df_6.columns[3]:'Solar (MWh)',df_6.columns[4]:'Non-Solar (MWh)',df_6.columns[5]:'Hydro (MWh)',df_6.columns[6]:'MCP (Rs/MWh)',df_6.columns[7]:'Weighted MCP (Rs/MWh)'})
df_6.drop([4,5], axis=0, inplace=True)
df_6
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-03-2022  00 - 01                        218.3           0
# 7           NaN  01 - 02                        218.3           0
# 8           NaN  02 - 03                        218.3           0
# 9           NaN  03 - 04                        218.3           0
# 10          NaN  04 - 05                        218.3           0
# ..          ...      ...                          ...         ...
# 872         NaN  Average                       280.26      126.94
# 873  31-03-2022    Total                      5315.40     2009.75
# 874         NaN      Max                       506.48      355.68
# 875         NaN      Min                       128.55        0.00
# 876         NaN  Average                       221.48       83.74
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6             218.3           0      3663.48               3663.48
# ...

# %%
df_7=pd.read_excel("/content/MarketHour (7).xlsx")
df_7=df_7.iloc[4:,:]
df_7=df_7.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df_7 =df_7.rename(columns={df_7.columns[0]:'Date',df_7.columns[1]:'Time',df_7.columns[2]: 'Final Scheduled Volume (MWh)',df_7.columns[3]:'Solar (MWh)',df_7.columns[4]:'Non-Solar (MWh)',df_7.columns[5]:'Hydro (MWh)',df_7.columns[6]:'MCP (Rs/MWh)',df_7.columns[7]:'Weighted MCP (Rs/MWh)'})
df_7.drop([4,5], axis=0, inplace=True)
df_7
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-04-2022  00 - 01                       152.93           0
# 7           NaN  01 - 02                       153.38           0
# 8           NaN  02 - 03                       153.18           0
# 9           NaN  03 - 04                       152.98           0
# 10          NaN  04 - 05                       152.83           0
# ..          ...      ...                          ...         ...
# 844         NaN  Average                       165.71       40.95
# 845  30-04-2022    Total                      2852.53      399.33
# 846         NaN      Max                       154.25       55.15
# 847         NaN      Min                       101.10        0.00
# 848         NaN  Average                       118.86       16.64
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6            152.93           0     20000.00              20000.00
# ...

# %%
df_8=pd.read_excel("/content/MarketHour (8).xlsx")
df_8=df_8.iloc[4:,:]
df_8=df_8.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df_8 =df_8.rename(columns={df_8.columns[0]:'Date',df_8.columns[1]:'Time',df_8.columns[2]: 'Final Scheduled Volume (MWh)',df_8.columns[3]:'Solar (MWh)',df_8.columns[4]:'Non-Solar (MWh)',df_8.columns[5]:'Hydro (MWh)',df_8.columns[6]:'MCP (Rs/MWh)',df_8.columns[7]:'Weighted MCP (Rs/MWh)'})
df_8.drop([4,5], axis=0, inplace=True)
df_8
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-05-2022  00 - 01                         79.7           0
# 7           NaN  01 - 02                         79.7           0
# 8           NaN  02 - 03                         79.7           0
# 9           NaN  03 - 04                         79.7           0
# 10          NaN  04 - 05                         79.7           0
# ..          ...      ...                          ...         ...
# 872         NaN  Average                       403.90      225.11
# 873  31-05-2022    Total                      6355.45     3800.74
# 874         NaN      Max                       535.15      426.55
# 875         NaN      Min                        97.10        0.00
# 876         NaN  Average                       264.81      158.36
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6              79.7           0     12000.00              12000.00
# ...

# %%
df_9=pd.read_excel("/content/MarketHour (9).xlsx")
df_9=df_9.iloc[4:,:]
df_9=df_9.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
df_9 =df_9.rename(columns={df_9.columns[0]:'Date',df_9.columns[1]:'Time',df_9.columns[2]: 'Final Scheduled Volume (MWh)',df_9.columns[3]:'Solar (MWh)',df_9.columns[4]:'Non-Solar (MWh)',df_9.columns[5]:'Hydro (MWh)',df_9.columns[6]:'MCP (Rs/MWh)',df_9.columns[7]:'Weighted MCP (Rs/MWh)'})
df_9.drop([4,5], axis=0, inplace=True)
df_9
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-06-2022  00 - 01                        45.45           0
# 7           NaN  01 - 02                         35.1           0
# 8           NaN  02 - 03                         35.1           0
# 9           NaN  03 - 04                         35.1           0
# 10          NaN  04 - 05                         35.1           0
# ..          ...      ...                          ...         ...
# 844         NaN  Average                       927.93      563.69
# 845  30-06-2022    Total                     19550.09    12769.46
# 846         NaN      Max                      1623.98     1438.60
# 847         NaN      Min                       213.70        0.00
# 848         NaN  Average                       814.59      532.06
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6             45.45           0     11499.46              11613.29
# ...

# %%
df = df.iloc[:121,:]
df
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    27-10-2021  00 - 01                          1.6           0
# 7           NaN  01 - 02                          1.6           0
# 8           NaN  02 - 03                          1.3           0
# 9           NaN  03 - 04                          1.6           0
# 10          NaN  04 - 05                          1.6           0
# ..          ...      ...                          ...         ...
# 122         NaN  20 - 21                          3.9           0
# 123         NaN  21 - 22                          3.9           0
# 124         NaN  22 - 23                          1.3           0
# 125         NaN  23 - 24                          1.3           0
# 126         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6               1.6           0      4600.97               4600.97
# ...

# %%
df["Date"]=df["Date"].fillna(method='ffill')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df['Time']=df['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dt_series = df['Date'] + ' ' + df['Time']
dt_series = pd.to_datetime(dt_series, dayfirst=True)
dt_series
# Out:
# 6     2021-10-27 00:00:00
# 7     2021-10-27 01:00:00
# 8     2021-10-27 02:00:00
# 9     2021-10-27 03:00:00
# 10    2021-10-27 04:00:00
#               ...
# 122   2021-10-31 20:00:00
# 123   2021-10-31 21:00:00
# 124   2021-10-31 22:00:00
# 125   2021-10-31 23:00:00
# 126                   NaT
# Length: 121, dtype: datetime64[ns]

# %%
df = df.drop(columns=['Date', 'Time'], axis=1)
df.insert(loc=0, column='DateTime', value=dt_series)
df
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2021-10-27 00:00:00                           1.6          0.0
# 7   2021-10-27 01:00:00                           1.6          0.0
# 8   2021-10-27 02:00:00                           1.3          0.0
# 9   2021-10-27 03:00:00                           1.6          0.0
# 10  2021-10-27 04:00:00                           1.6          0.0
# ..                  ...                           ...          ...
# 122 2021-10-31 20:00:00                           3.9          0.0
# 123 2021-10-31 21:00:00                           3.9          0.0
# 124 2021-10-31 22:00:00                           1.3          0.0
# 125 2021-10-31 23:00:00                           1.3          0.0
# 126                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6                1.6          0.0       4600.97                4600.97
# ...

# %%
plt.figure(figsize=(10,8))
plt.plot(df["DateTime"],df["MCP (Rs/MWh)"])
plt.xlabel("Days")
plt.ylabel("MCP (Rs/MWh)")
plt.title("Daily varation of price in India in Rupees/Mwh")
plt.savefig("Daily Indian")

# %%
df_1 = df_1.iloc[:721,:]
df_1
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-11-2021  00 - 01                          8.4           0
# 7           NaN  01 - 02                          8.4           0
# 8           NaN  02 - 03                          8.4           0
# 9           NaN  03 - 04                          8.1           0
# 10          NaN  04 - 05                          8.4           0
# ..          ...      ...                          ...         ...
# 722         NaN  20 - 21                         26.4           0
# 723         NaN  21 - 22                         21.3           0
# 724         NaN  22 - 23                         26.4           0
# 725         NaN  23 - 24                         26.4           0
# 726         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6               8.4           0      4600.79               4600.79
# ...

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df_1[cols] = df_1[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 721 entries, 6 to 726
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          30 non-null     object
#  1   Time                          720 non-null    object
#  2   Final Scheduled Volume (MWh)  720 non-null    float64
#  3   Solar (MWh)                   720 non-null    float64
#  4   Non-Solar (MWh)               720 non-null    float64
#  5   Hydro (MWh)                   720 non-null    float64
#  6   MCP (Rs/MWh)                  720 non-null    float64
#  7   Weighted MCP (Rs/MWh)         720 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 50.7+ KB

# %%
df_1["Date"]=df_1["Date"].fillna(method='ffill')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1
# Out:
#            Date     Time  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6    01-11-2021  00 - 01                           8.4          0.0
# 7    01-11-2021  01 - 02                           8.4          0.0
# 8    01-11-2021  02 - 03                           8.4          0.0
# 9    01-11-2021  03 - 04                           8.1          0.0
# 10   01-11-2021  04 - 05                           8.4          0.0
# ..          ...      ...                           ...          ...
# 722  30-11-2021  20 - 21                          26.4          0.0
# 723  30-11-2021  21 - 22                          21.3          0.0
# 724  30-11-2021  22 - 23                          26.4          0.0
# 725  30-11-2021  23 - 24                          26.4          0.0
# 726  30-11-2021      NaN                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6                8.4          0.0       4600.79                4600.79
# ...

# %%
df_1['Time']=df_1['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1
# Out:
#            Date Time  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6    01-11-2021  00                            8.4          0.0
# 7    01-11-2021  01                            8.4          0.0
# 8    01-11-2021  02                            8.4          0.0
# 9    01-11-2021  03                            8.1          0.0
# 10   01-11-2021  04                            8.4          0.0
# ..          ...  ...                           ...          ...
# 722  30-11-2021  20                           26.4          0.0
# 723  30-11-2021  21                           21.3          0.0
# 724  30-11-2021  22                           26.4          0.0
# 725  30-11-2021  23                           26.4          0.0
# 726  30-11-2021  NaN                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6                8.4          0.0       4600.79                4600.79
# ...

# %%
dt_series = df_1['Date'] + ' ' + df_1['Time']
dt_series = pd.to_datetime(dt_series, dayfirst=True)
#dt_series = dt_series.dt.strftime('%Y-%m-%d')
dt_series
# Out:
# 6     2021-11-01 00:00:00
# 7     2021-11-01 01:00:00
# 8     2021-11-01 02:00:00
# 9     2021-11-01 03:00:00
# 10    2021-11-01 04:00:00
#               ...
# 722   2021-11-30 20:00:00
# 723   2021-11-30 21:00:00
# 724   2021-11-30 22:00:00
# 725   2021-11-30 23:00:00
# 726                   NaT
# Length: 721, dtype: datetime64[ns]

# %%
df_1 = df_1.drop(columns=['Date', 'Time'], axis=1)
df_1.insert(loc=0, column='DateTime', value=dt_series)
df_1
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2021-11-01 00:00:00                           8.4          0.0
# 7   2021-11-01 01:00:00                           8.4          0.0
# 8   2021-11-01 02:00:00                           8.4          0.0
# 9   2021-11-01 03:00:00                           8.1          0.0
# 10  2021-11-01 04:00:00                           8.4          0.0
# ..                  ...                           ...          ...
# 722 2021-11-30 20:00:00                          26.4          0.0
# 723 2021-11-30 21:00:00                          21.3          0.0
# 724 2021-11-30 22:00:00                          26.4          0.0
# 725 2021-11-30 23:00:00                          26.4          0.0
# 726                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6                8.4          0.0       4600.79                4600.79
# ...

# %%
plt.figure(figsize=(10,8))
plt.scatter(df_1["DateTime"],df_1["MCP (Rs/MWh)"])

# %%
df_2 = df_2.iloc[:745,:]
df_2
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-12-2021  00 - 01                       107.75           0
# 7           NaN  01 - 02                       100.75           0
# 8           NaN  02 - 03                        100.5           0
# 9           NaN  03 - 04                        97.75           0
# 10          NaN  04 - 05                        87.25           0
# ..          ...      ...                          ...         ...
# 746         NaN  20 - 21                        69.78           0
# 747         NaN  21 - 22                         66.3           0
# 748         NaN  22 - 23                         66.5           0
# 749         NaN  23 - 24                        74.28           0
# 750         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6            107.75           0      4599.69               4599.70
# ...

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df_2[cols] = df_2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_2["Date"]=df_2["Date"].fillna(method='ffill')
df_2['Time']=df_2['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dt_series = df_2['Date'] + ' ' + df_2['Time']
dt_series = pd.to_datetime(dt_series, dayfirst=True)
dt_series
# Out:
# 6     2021-12-01 00:00:00
# 7     2021-12-01 01:00:00
# 8     2021-12-01 02:00:00
# 9     2021-12-01 03:00:00
# 10    2021-12-01 04:00:00
#               ...
# 746   2021-12-31 20:00:00
# 747   2021-12-31 21:00:00
# 748   2021-12-31 22:00:00
# 749   2021-12-31 23:00:00
# 750                   NaT
# Length: 745, dtype: datetime64[ns]

# %%
df_2 = df_2.drop(columns=['Date', 'Time'], axis=1)
df_2.insert(loc=0, column='DateTime', value=dt_series)
df_2
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2021-12-01 00:00:00                        107.75          0.0
# 7   2021-12-01 01:00:00                        100.75          0.0
# 8   2021-12-01 02:00:00                        100.50          0.0
# 9   2021-12-01 03:00:00                         97.75          0.0
# 10  2021-12-01 04:00:00                         87.25          0.0
# ..                  ...                           ...          ...
# 746 2021-12-31 20:00:00                         69.78          0.0
# 747 2021-12-31 21:00:00                         66.30          0.0
# 748 2021-12-31 22:00:00                         66.50          0.0
# 749 2021-12-31 23:00:00                         74.28          0.0
# 750                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6             107.75          0.0       4599.69                4599.70
# ...

# %%
df_2.isnull().sum()
# Out:
# DateTime                        1
# Final Scheduled Volume (MWh)    1
# Solar (MWh)                     1
# Non-Solar (MWh)                 1
# Hydro (MWh)                     1
# MCP (Rs/MWh)                    1
# Weighted MCP (Rs/MWh)           1
# dtype: int64

# %%
df_3 = df_3.iloc[:745,:]
df_3
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-01-2022  00 - 01                          105           0
# 7           NaN  01 - 02                        94.75           0
# 8           NaN  02 - 03                         95.5           0
# 9           NaN  03 - 04                        93.25           0
# 10          NaN  04 - 05                        78.25           0
# ..          ...      ...                          ...         ...
# 746         NaN  20 - 21                       204.58           0
# 747         NaN  21 - 22                        203.3           0
# 748         NaN  22 - 23                       203.08           0
# 749         NaN  23 - 24                          203           0
# 750         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6               105           0      4599.08               4599.08
# ...

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df_3[cols] = df_3[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_3["Date"]=df_3["Date"].fillna(method='ffill')
df_3['Time']=df_3['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dt_series = df_3['Date'] + ' ' + df_3['Time']
dt_series = pd.to_datetime(dt_series, dayfirst=True)
dt_series
# Out:
# 6     2022-01-01 00:00:00
# 7     2022-01-01 01:00:00
# 8     2022-01-01 02:00:00
# 9     2022-01-01 03:00:00
# 10    2022-01-01 04:00:00
#               ...
# 746   2022-01-31 20:00:00
# 747   2022-01-31 21:00:00
# 748   2022-01-31 22:00:00
# 749   2022-01-31 23:00:00
# 750                   NaT
# Length: 745, dtype: datetime64[ns]

# %%
df_3.head(100)
# Out:
#            Date Time  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6    01-01-2022  00                         105.00          0.0
# 7    01-01-2022  01                          94.75          0.0
# 8    01-01-2022  02                          95.50          0.0
# 9    01-01-2022  03                          93.25          0.0
# 10   01-01-2022  04                          78.25          0.0
# ..          ...  ...                           ...          ...
# 101  04-01-2022  23                          98.70          0.0
# 102  05-01-2022  00                         163.15          0.0
# 103  05-01-2022  01                         152.85          0.0
# 104  05-01-2022  02                         154.35          0.0
# 105  05-01-2022  03                         152.75          0.0
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6             105.00          0.0       4599.08                4599.08
# ...

# %%
df_3= df_3.drop(columns=['Date', 'Time'], axis=1)
df_3.insert(loc=0, column='DateTime', value=dt_series)
df_3
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2022-01-01 00:00:00                        105.00          0.0
# 7   2022-01-01 01:00:00                         94.75          0.0
# 8   2022-01-01 02:00:00                         95.50          0.0
# 9   2022-01-01 03:00:00                         93.25          0.0
# 10  2022-01-01 04:00:00                         78.25          0.0
# ..                  ...                           ...          ...
# 746 2022-01-31 20:00:00                        204.58          0.0
# 747 2022-01-31 21:00:00                        203.30          0.0
# 748 2022-01-31 22:00:00                        203.08          0.0
# 749 2022-01-31 23:00:00                        203.00          0.0
# 750                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6             105.00          0.0       4599.08                4599.08
# ...

# %%
df_5 = df_5.iloc[:673,:]
df_5
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-02-2022  00 - 01                       177.38           0
# 7           NaN  01 - 02                        176.9           0
# 8           NaN  02 - 03                       177.48           0
# 9           NaN  03 - 04                       177.98           0
# 10          NaN  04 - 05                       176.75           0
# ..          ...      ...                          ...         ...
# 674         NaN  20 - 21                        266.1           0
# 675         NaN  21 - 22                          259           0
# 676         NaN  22 - 23                          259           0
# 677         NaN  23 - 24                       263.38           0
# 678         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6            177.38           0      3826.18               3827.98
# ...

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df_5[cols] = df_5[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_5["Date"]=df_5["Date"].fillna(method='ffill')
df_5['Time']=df_5['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dt_series = df_5['Date'] + ' ' + df_5['Time']
dt_series = pd.to_datetime(dt_series, dayfirst=True)
dt_series
# Out:
# 6     2022-02-01 00:00:00
# 7     2022-02-01 01:00:00
# 8     2022-02-01 02:00:00
# 9     2022-02-01 03:00:00
# 10    2022-02-01 04:00:00
#               ...
# 674   2022-02-28 20:00:00
# 675   2022-02-28 21:00:00
# 676   2022-02-28 22:00:00
# 677   2022-02-28 23:00:00
# 678                   NaT
# Length: 673, dtype: datetime64[ns]

# %%
df_5= df_5.drop(columns=['Date', 'Time'], axis=1)
df_5.insert(loc=0, column='DateTime', value=dt_series)
df_5
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2022-02-01 00:00:00                        177.38          0.0
# 7   2022-02-01 01:00:00                        176.90          0.0
# 8   2022-02-01 02:00:00                        177.48          0.0
# 9   2022-02-01 03:00:00                        177.98          0.0
# 10  2022-02-01 04:00:00                        176.75          0.0
# ..                  ...                           ...          ...
# 674 2022-02-28 20:00:00                        266.10          0.0
# 675 2022-02-28 21:00:00                        259.00          0.0
# 676 2022-02-28 22:00:00                        259.00          0.0
# 677 2022-02-28 23:00:00                        263.38          0.0
# 678                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6             177.38          0.0       3826.18                3827.98
# ...

# %%
df_6 = df_6.iloc[:745,:]
df_6
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-03-2022  00 - 01                        218.3           0
# 7           NaN  01 - 02                        218.3           0
# 8           NaN  02 - 03                        218.3           0
# 9           NaN  03 - 04                        218.3           0
# 10          NaN  04 - 05                        218.3           0
# ..          ...      ...                          ...         ...
# 746         NaN  20 - 21                       161.83           0
# 747         NaN  21 - 22                       139.75           0
# 748         NaN  22 - 23                       133.95           0
# 749         NaN  23 - 24                       128.55           0
# 750         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6             218.3           0      3663.48               3663.48
# ...

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df_6[cols] = df_6[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_6["Date"]=df_6["Date"].fillna(method='ffill')
df_6['Time']=df_6['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dt_series = df_6['Date'] + ' ' + df_6['Time']
dt_series = pd.to_datetime(dt_series, dayfirst=True)
dt_series
# Out:
# 6     2022-03-01 00:00:00
# 7     2022-03-01 01:00:00
# 8     2022-03-01 02:00:00
# 9     2022-03-01 03:00:00
# 10    2022-03-01 04:00:00
#               ...
# 746   2022-03-31 20:00:00
# 747   2022-03-31 21:00:00
# 748   2022-03-31 22:00:00
# 749   2022-03-31 23:00:00
# 750                   NaT
# Length: 745, dtype: datetime64[ns]

# %%
df_6= df_6.drop(columns=['Date', 'Time'], axis=1)
df_6.insert(loc=0, column='DateTime', value=dt_series)
df_6
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2022-03-01 00:00:00                        218.30          0.0
# 7   2022-03-01 01:00:00                        218.30          0.0
# 8   2022-03-01 02:00:00                        218.30          0.0
# 9   2022-03-01 03:00:00                        218.30          0.0
# 10  2022-03-01 04:00:00                        218.30          0.0
# ..                  ...                           ...          ...
# 746 2022-03-31 20:00:00                        161.83          0.0
# 747 2022-03-31 21:00:00                        139.75          0.0
# 748 2022-03-31 22:00:00                        133.95          0.0
# 749 2022-03-31 23:00:00                        128.55          0.0
# 750                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6             218.30          0.0       3663.48                3663.48
# ...

# %%
df_7 = df_7.iloc[:721,:]
df_7
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-04-2022  00 - 01                       152.93           0
# 7           NaN  01 - 02                       153.38           0
# 8           NaN  02 - 03                       153.18           0
# 9           NaN  03 - 04                       152.98           0
# 10          NaN  04 - 05                       152.83           0
# ..          ...      ...                          ...         ...
# 722         NaN  20 - 21                        102.1           0
# 723         NaN  21 - 22                        101.1           0
# 724         NaN  22 - 23                        101.1           0
# 725         NaN  23 - 24                        101.1           0
# 726         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6            152.93           0     20000.00              20000.00
# ...

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df_7[cols] = df_7[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_7["Date"]=df_7["Date"].fillna(method='ffill')
df_7['Time']=df_7['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dt_series = df_7['Date'] + ' ' + df_7['Time']
dt_series =pd.to_datetime(dt_series, dayfirst=True)
dt_series
# Out:
# 6     2022-04-01 00:00:00
# 7     2022-04-01 01:00:00
# 8     2022-04-01 02:00:00
# 9     2022-04-01 03:00:00
# 10    2022-04-01 04:00:00
#               ...
# 722   2022-04-30 20:00:00
# 723   2022-04-30 21:00:00
# 724   2022-04-30 22:00:00
# 725   2022-04-30 23:00:00
# 726                   NaT
# Length: 721, dtype: datetime64[ns]

# %%
df_7= df_7.drop(columns=['Date', 'Time'], axis=1)
df_7.insert(loc=0, column='DateTime', value=dt_series)
df_7
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2022-04-01 00:00:00                        152.93          0.0
# 7   2022-04-01 01:00:00                        153.38          0.0
# 8   2022-04-01 02:00:00                        153.18          0.0
# 9   2022-04-01 03:00:00                        152.98          0.0
# 10  2022-04-01 04:00:00                        152.83          0.0
# ..                  ...                           ...          ...
# 722 2022-04-30 20:00:00                        102.10          0.0
# 723 2022-04-30 21:00:00                        101.10          0.0
# 724 2022-04-30 22:00:00                        101.10          0.0
# 725 2022-04-30 23:00:00                        101.10          0.0
# 726                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6             152.93          0.0       20000.0                20000.0
# ...

# %%
df_8 = df_8.iloc[:745,:]
df_8
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-05-2022  00 - 01                         79.7           0
# 7           NaN  01 - 02                         79.7           0
# 8           NaN  02 - 03                         79.7           0
# 9           NaN  03 - 04                         79.7           0
# 10          NaN  04 - 05                         79.7           0
# ..          ...      ...                          ...         ...
# 746         NaN  20 - 21                        97.35           0
# 747         NaN  21 - 22                       101.35           0
# 748         NaN  22 - 23                        108.1           0
# 749         NaN  23 - 24                       119.28           0
# 750         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6              79.7           0     12000.00              12000.00
# ...

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df_8[cols] = df_8[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_8["Date"]=df_8["Date"].fillna(method='ffill')
df_8['Time']=df_8['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dt_series = df_8['Date'] + ' ' + df_8['Time']
dt_series = pd.to_datetime(dt_series, dayfirst=True)
dt_series
# Out:
# 6     2022-05-01 00:00:00
# 7     2022-05-01 01:00:00
# 8     2022-05-01 02:00:00
# 9     2022-05-01 03:00:00
# 10    2022-05-01 04:00:00
#               ...
# 746   2022-05-31 20:00:00
# 747   2022-05-31 21:00:00
# 748   2022-05-31 22:00:00
# 749   2022-05-31 23:00:00
# 750                   NaT
# Length: 745, dtype: datetime64[ns]

# %%
df_8= df_8.drop(columns=['Date', 'Time'], axis=1)
df_8.insert(loc=0, column='DateTime', value=dt_series)
df_8
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2022-05-01 00:00:00                         79.70          0.0
# 7   2022-05-01 01:00:00                         79.70          0.0
# 8   2022-05-01 02:00:00                         79.70          0.0
# 9   2022-05-01 03:00:00                         79.70          0.0
# 10  2022-05-01 04:00:00                         79.70          0.0
# ..                  ...                           ...          ...
# 746 2022-05-31 20:00:00                         97.35          0.0
# 747 2022-05-31 21:00:00                        101.35          0.0
# 748 2022-05-31 22:00:00                        108.10          0.0
# 749 2022-05-31 23:00:00                        119.28          0.0
# 750                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6              79.70          0.0      12000.00               12000.00
# ...

# %%
df_9 = df_9.iloc[:721,:]
df_9
# Out:
#            Date     Time Final Scheduled Volume (MWh) Solar (MWh)  \
# 6    01-06-2022  00 - 01                        45.45           0
# 7           NaN  01 - 02                         35.1           0
# 8           NaN  02 - 03                         35.1           0
# 9           NaN  03 - 04                         35.1           0
# 10          NaN  04 - 05                         35.1           0
# ..          ...      ...                          ...         ...
# 722         NaN  20 - 21                       275.35           0
# 723         NaN  21 - 22                        286.3           0
# 724         NaN  22 - 23                       284.77           0
# 725         NaN  23 - 24                       281.63           0
# 726         NaN      NaN                          NaN         NaN
#
#     Non-Solar (MWh) Hydro (MWh) MCP (Rs/MWh) Weighted MCP (Rs/MWh)
# 6             45.45           0     11499.46              11613.29
# ...

# %%
cols = ['Final Scheduled Volume (MWh)', 'Solar (MWh)',
       'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
       'Weighted MCP (Rs/MWh)']
df_9[cols] = df_9[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_9["Date"]=df_9["Date"].fillna(method='ffill')
df_9['Time']=df_9['Time'].str.rsplit('-', 1).str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dt_series = df_9['Date'] + ' ' + df_9['Time']
dt_series = pd.to_datetime(dt_series, dayfirst=True)
dt_series
# Out:
# 6     2022-06-01 00:00:00
# 7     2022-06-01 01:00:00
# 8     2022-06-01 02:00:00
# 9     2022-06-01 03:00:00
# 10    2022-06-01 04:00:00
#               ...
# 722   2022-06-30 20:00:00
# 723   2022-06-30 21:00:00
# 724   2022-06-30 22:00:00
# 725   2022-06-30 23:00:00
# 726                   NaT
# Length: 721, dtype: datetime64[ns]

# %%
df_9= df_9.drop(columns=['Date', 'Time'], axis=1)
df_9.insert(loc=0, column='DateTime', value=dt_series)
df_9
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2022-06-01 00:00:00                         45.45          0.0
# 7   2022-06-01 01:00:00                         35.10          0.0
# 8   2022-06-01 02:00:00                         35.10          0.0
# 9   2022-06-01 03:00:00                         35.10          0.0
# 10  2022-06-01 04:00:00                         35.10          0.0
# ..                  ...                           ...          ...
# 722 2022-06-30 20:00:00                        275.35          0.0
# 723 2022-06-30 21:00:00                        286.30          0.0
# 724 2022-06-30 22:00:00                        284.77          0.0
# 725 2022-06-30 23:00:00                        281.63          0.0
# 726                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6              45.45          0.0      11499.46               11613.29
# ...

# %%
a =[df,df_1,df_2,df_3,df_5,df_6,df_7,df_8,df_9]
result= pd.concat(a)
result
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2021-10-27 00:00:00                          1.60          0.0
# 7   2021-10-27 01:00:00                          1.60          0.0
# 8   2021-10-27 02:00:00                          1.30          0.0
# 9   2021-10-27 03:00:00                          1.60          0.0
# 10  2021-10-27 04:00:00                          1.60          0.0
# ..                  ...                           ...          ...
# 722 2022-06-30 20:00:00                        275.35          0.0
# 723 2022-06-30 21:00:00                        286.30          0.0
# 724 2022-06-30 22:00:00                        284.77          0.0
# 725 2022-06-30 23:00:00                        281.63          0.0
# 726                 NaT                           NaN          NaN
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6               1.60          0.0       4600.97                4600.97
# ...

# %%
result.isnull().sum()
# Out:
# DateTime                        9
# Final Scheduled Volume (MWh)    9
# Solar (MWh)                     9
# Non-Solar (MWh)                 9
# Hydro (MWh)                     9
# MCP (Rs/MWh)                    9
# Weighted MCP (Rs/MWh)           9
# dtype: int64

# %%
result = result.dropna(axis=0)

# %%
result.head(150)
# Out:
#               DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6  2021-10-27 00:00:00                          1.60          0.0
# 7  2021-10-27 01:00:00                          1.60          0.0
# 8  2021-10-27 02:00:00                          1.30          0.0
# 9  2021-10-27 03:00:00                          1.60          0.0
# 10 2021-10-27 04:00:00                          1.60          0.0
# ..                 ...                           ...          ...
# 31 2021-11-02 01:00:00                        131.75          0.0
# 32 2021-11-02 02:00:00                        135.75          0.0
# 33 2021-11-02 03:00:00                        127.75          0.0
# 34 2021-11-02 04:00:00                        118.25          0.0
# 35 2021-11-02 05:00:00                        143.40          0.0
#
#     Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)
# 6              1.60          0.0       4600.97                4600.97
# ...

# %%
plt.figure(figsize=(10,8))
plt.scatter(result["DateTime"],result["MCP (Rs/MWh)"])

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5928 entries, 6 to 725
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   DateTime                      5928 non-null   datetime64[ns]
#  1   Final Scheduled Volume (MWh)  5928 non-null   float64
#  2   Solar (MWh)                   5928 non-null   float64
#  3   Non-Solar (MWh)               5928 non-null   float64
#  4   Hydro (MWh)                   5928 non-null   float64
#  5   MCP (Rs/MWh)                  5928 non-null   float64
#  6   Weighted MCP (Rs/MWh)         5928 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 370.5 KB

# %%
dt_series = result["DateTime"]

# %%
year_series = dt_series.dt.year
month_series = dt_series.dt.month
day_series = dt_series.dt.day
day_name_series = dt_series.dt.day_name()

# %%
result['Year'] = year_series
result['Month'] = month_series
result['Day'] = day_series
result['Day Name'] = day_name_series
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
result
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2021-10-27 00:00:00                          1.60         0.00
# 7   2021-10-27 01:00:00                          1.60         0.00
# 8   2021-10-27 02:00:00                          1.30         0.00
# 9   2021-10-27 03:00:00                          1.60         0.00
# 10  2021-10-27 04:00:00                          1.60         0.00
# ..                  ...                           ...          ...
# 721 2022-06-30 19:00:00                        213.70        21.75
# 722 2022-06-30 20:00:00                        275.35         0.00
# 723 2022-06-30 21:00:00                        286.30         0.00
# 724 2022-06-30 22:00:00                        284.77         0.00
# 725 2022-06-30 23:00:00                        281.63         0.00
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)  Year  \
# 6               1.60          0.0       4600.97                4600.97  2021
# ...

# %%
data = result.sort_values(by='DateTime')
data
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2021-10-27 00:00:00                          1.60         0.00
# 7   2021-10-27 01:00:00                          1.60         0.00
# 8   2021-10-27 02:00:00                          1.30         0.00
# 9   2021-10-27 03:00:00                          1.60         0.00
# 10  2021-10-27 04:00:00                          1.60         0.00
# ..                  ...                           ...          ...
# 721 2022-06-30 19:00:00                        213.70        21.75
# 722 2022-06-30 20:00:00                        275.35         0.00
# 723 2022-06-30 21:00:00                        286.30         0.00
# 724 2022-06-30 22:00:00                        284.77         0.00
# 725 2022-06-30 23:00:00                        281.63         0.00
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)  Year  \
# 6               1.60          0.0       4600.97                4600.97  2021
# ...

# %%
group_month = data.groupby(by='Month',as_index = False)
group_month

# %%
months = data['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month.mean()['Month'], group_month.mean()['MCP (Rs/MWh)'],'r-o')
plt.title("Price v/s month for the year 2021 ")
plt.ylabel("MCP (Rs/MWh)")
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
result_2021 = result[result["Year"]==2021]
result_2021
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2021-10-27 00:00:00                          1.60          0.0
# 7   2021-10-27 01:00:00                          1.60          0.0
# 8   2021-10-27 02:00:00                          1.30          0.0
# 9   2021-10-27 03:00:00                          1.60          0.0
# 10  2021-10-27 04:00:00                          1.60          0.0
# ..                  ...                           ...          ...
# 745 2021-12-31 19:00:00                         69.18          0.0
# 746 2021-12-31 20:00:00                         69.78          0.0
# 747 2021-12-31 21:00:00                         66.30          0.0
# 748 2021-12-31 22:00:00                         66.50          0.0
# 749 2021-12-31 23:00:00                         74.28          0.0
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)  Year  \
# 6               1.60          0.0       4600.97                4600.97  2021
# ...

# %%
sns.distplot(result_2021['MCP (Rs/MWh)'])
plt.savefig("Distributionplot for Indian price data ")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import missingno as msno
msno.bar(result_2021)
plt.savefig("missing value for price Indian")

# %%
result_2022 =result[result["Year"]==2022]

# %%
group_month_2021 = result_2021.groupby(by='Month',as_index = False)
group_month_2021

# %%
group_month_2021.agg(func=['mean', 'std', 'median'])
# Out:
#       Final Scheduled Volume (MWh)                      Solar (MWh)  \
#                               mean         std   median        mean
# Month
# 10                      161.783250  186.852368   85.565  143.284583
# 11                      207.592569  286.915962   52.815  179.516250
# 12                      211.295242  238.243859  119.375  138.000766
#
#                          Non-Solar (MWh)                    Hydro (MWh)  ...  \
#               std median            mean        std  median        mean  ...
# Month                                                                    ...
# 10     193.423976  0.215       18.499167  34.450892   4.290         0.0  ...
# 11     293.898522  0.155       28.076903  31.970635  16.705         0.0  ...
# 12     250.927802  0.100       73.295094  36.757533  61.090         0.0  ...
#
#       MCP (Rs/MWh) Weighted MCP (Rs/MWh)                           Year       \
# ...

# %%
result_2021.head(150)
# Out:
#               DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6  2021-10-27 00:00:00                          1.60          0.0
# 7  2021-10-27 01:00:00                          1.60          0.0
# 8  2021-10-27 02:00:00                          1.30          0.0
# 9  2021-10-27 03:00:00                          1.60          0.0
# 10 2021-10-27 04:00:00                          1.60          0.0
# ..                 ...                           ...          ...
# 31 2021-11-02 01:00:00                        131.75          0.0
# 32 2021-11-02 02:00:00                        135.75          0.0
# 33 2021-11-02 03:00:00                        127.75          0.0
# 34 2021-11-02 04:00:00                        118.25          0.0
# 35 2021-11-02 05:00:00                        143.40          0.0
#
#     Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)  Year  \
# 6              1.60          0.0       4600.97                4600.97  2021
# ...

# %%
result_2021["Month"].unique()
# Out:
# array([10, 11, 12])

# %%
result_2021['DateTime'].dt.month_name().unique()
# Out:
# array(['October', 'November', 'December'], dtype=object)

# %%
months = result_2021['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_2021.mean()['Month'], group_month_2021.mean()['MCP (Rs/MWh)'],'r-o')
plt.title("Price v/s month for the year 2021 ")
plt.ylabel("MCP (Rs/MWh)")
plt.xticks(ticks=group_month_2021.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
months = result_2021['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_2021.mean()['Month'], group_month_2021.mean()["Final Scheduled Volume (MWh)"],'r-o')
plt.title("Price v/s month for the year 2021 ")
plt.ylabel("MCP (Rs/MWh)")
plt.xticks(ticks=group_month_2021.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
# create figure and axis objects with subplots()
months = result_2021['DateTime'].dt.month_name().unique()
fig=plt.figure(figsize=(15, 5))
ax = fig.subplots()
plt.xticks(ticks=group_month_2021.median()['Month'], labels=months,rotation=45)
# make a plot
ax.plot(group_month_2021.mean()['Month'], group_month_2021.mean()["Final Scheduled Volume (MWh)"],'r-o')
# set x-axis label
ax.set_xlabel("months",fontsize=14)
# set y-axis label
ax.set_ylabel("total forecast",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(group_month_2021.mean()['Month'], group_month_2021.mean()['MCP (Rs/MWh)'],'g-o')
ax2.set_ylabel("price",color="green",fontsize=14)
plt.title("Price v/s total forecast in year 2021" )
plt.savefig("2021 total forecast")

# %%
months = result_2021['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_2021.mean()['Month'], group_month_2021.mean()["Solar (MWh)"],'r-o')
plt.title("Solar v/s month for the year 2021 ")
plt.ylabel("MCP (Rs/MWh)")
plt.xticks(ticks=group_month_2021.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
dt_series_1 = result_2021["DateTime"]
hour_series = dt_series_1.dt.hour
min_series = dt_series_1.dt.minute
sec_series = dt_series_1.dt.second

# %%
result_2021['Hours'] = hour_series
result_2021['minutes'] = min_series
result_2021['seconds'] = sec_series
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
result_2021
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2021-10-27 00:00:00                          1.60          0.0
# 7   2021-10-27 01:00:00                          1.60          0.0
# 8   2021-10-27 02:00:00                          1.30          0.0
# 9   2021-10-27 03:00:00                          1.60          0.0
# 10  2021-10-27 04:00:00                          1.60          0.0
# ..                  ...                           ...          ...
# 745 2021-12-31 19:00:00                         69.18          0.0
# 746 2021-12-31 20:00:00                         69.78          0.0
# 747 2021-12-31 21:00:00                         66.30          0.0
# 748 2021-12-31 22:00:00                         66.50          0.0
# 749 2021-12-31 23:00:00                         74.28          0.0
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)  Year  \
# 6               1.60          0.0       4600.97                4600.97  2021
# ...

# %%
estimate_solar_India=result_2021.pivot_table(index=['Hours'], columns=['Year', 'Month'], values='Solar (MWh)')

# %%
fig, axes = plt.subplots(figsize=(20, 15), sharex=True)
start, end = axes.get_ylim()

axes = sns.heatmap(estimate_solar_India)
#axes.title("Heatmap of Indian solar energy in year 2021")
axes.set_title("Heatmap of Indian solar energy in year 2021")
plt.savefig("Heatmap Total India energy 2021")

# %%
group_month_2022 = result_2022.groupby(by='Month',as_index = False)
group_month_2022

# %%
result_2022
# Out:
#                DateTime  Final Scheduled Volume (MWh)  Solar (MWh)  \
# 6   2022-01-01 00:00:00                        105.00         0.00
# 7   2022-01-01 01:00:00                         94.75         0.00
# 8   2022-01-01 02:00:00                         95.50         0.00
# 9   2022-01-01 03:00:00                         93.25         0.00
# 10  2022-01-01 04:00:00                         78.25         0.00
# ..                  ...                           ...          ...
# 721 2022-06-30 19:00:00                        213.70        21.75
# 722 2022-06-30 20:00:00                        275.35         0.00
# 723 2022-06-30 21:00:00                        286.30         0.00
# 724 2022-06-30 22:00:00                        284.77         0.00
# 725 2022-06-30 23:00:00                        281.63         0.00
#
#      Non-Solar (MWh)  Hydro (MWh)  MCP (Rs/MWh)  Weighted MCP (Rs/MWh)  Year  \
# 6             105.00          0.0       4599.08                4599.08  2022
# ...

# %%
months = result_2022['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_2022.mean()['Month'], group_month_2022.mean()['MCP (Rs/MWh)'],'r-o')
plt.title("Price v/s month for the year 2022 ")
plt.ylabel("MCP (Rs/MWh)")
plt.xticks(ticks=group_month_2022.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
months = result_2022['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_2022.mean()['Month'], group_month_2022.mean()["Final Scheduled Volume (MWh)"],'r-o')
plt.title("Price v/s month for the year 2022 ")
plt.ylabel("MCP (Rs/MWh)")
plt.xticks(ticks=group_month_2022.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
# create figure and axis objects with subplots()
months = result_2022['DateTime'].dt.month_name().unique()
fig=plt.figure(figsize=(15, 5))
ax = fig.subplots()
plt.xticks(ticks=group_month_2022.median()['Month'], labels=months,rotation=45)
# make a plot
ax.plot(group_month_2022.mean()['Month'], group_month_2022.mean()["Final Scheduled Volume (MWh)"],'r-o')
# set x-axis label
ax.set_xlabel("months",fontsize=14)
# set y-axis label
ax.set_ylabel("total forecast",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(group_month_2022.mean()['Month'], group_month_2022.mean()['MCP (Rs/MWh)'],'g-o')
ax2.set_ylabel("price",color="green",fontsize=14)
plt.title("Price v/s total forecast in year 2022" )
plt.savefig("2022 total forecast India")

# %%
months = result_2022['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month_2022.mean()['Month'], group_month_2022.mean()["Solar (MWh)"],'r-o')
plt.title("Solar v/s month for the year 2021 ")
plt.ylabel("MCP (Rs/MWh)")
plt.xticks(ticks=group_month_2022.median()['Month'], labels=months,rotation=45)
plt.show()

# %%
dt_series_1 = result_2022["DateTime"]
hour_series = dt_series_1.dt.hour
min_series = dt_series_1.dt.minute
sec_series = dt_series_1.dt.second

# %%
result_2022['Hours'] = hour_series
result_2022['minutes'] = min_series
result_2022['seconds'] = sec_series
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
estimate_solar_India_2=result_2022.pivot_table(index=['Hours'], columns=['Year', 'Month'], values='Solar (MWh)')

# %%
fig, axes = plt.subplots(figsize=(20, 15), sharex=True)
start, end = axes.get_ylim()

axes = sns.heatmap(estimate_solar_India_2)
axes.set_title("Heatmap of Indian solar energy(Mwh) in year 2022")
plt.savefig("Heatmap Total India energy 2022")

# %%
result_2021_new = result_2021

# %%
result_2022_new = result_2022

# %%
result_2021_new.columns
# Out:
# Index(['DateTime', 'Final Scheduled Volume (MWh)', 'Solar (MWh)',
#        'Non-Solar (MWh)', 'Hydro (MWh)', 'MCP (Rs/MWh)',
#        'Weighted MCP (Rs/MWh)', 'Year', 'Month', 'Day', 'Day Name', 'Hours',
#        'minutes', 'seconds'],
#       dtype='object')

# %%
result_2021_new['MCP (Rs/MWh)'] = result_2021_new['MCP (Rs/MWh)'].apply(lambda x: x / 80)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
result_2022_new['MCP (Rs/MWh)'] = result_2022_new['MCP (Rs/MWh)'].apply(lambda x: x / 80)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
group_month_2021_new = result_2021_new.groupby(by='Month',as_index = False)
group_month_2021_new

# %%
group_month_2022_new = result_2022_new.groupby(by='Month',as_index = False)
group_month_2022_new

# %%
price_df_2020 = pd.read_excel("/content/Gro_handelspreise_202201010000_202206302359.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
price_df_2020_ger = price_df_2020.iloc[5:,:3]

# %%
price_df_2020_ger=price_df_2020_ger.rename(columns={'Datenkategorie: Großhandelspreise':"Date","Unnamed: 1":"Time","Unnamed: 2":"Deutschland/Luxemburg[€/MWh]"})

# %%
price_df_2020_ger.drop(5,axis=0,inplace =True)
price_df_2020_ger
# Out:
#             Date   Time Deutschland/Luxemburg[€/MWh]
# 6     01.01.2022  00:00                        50.05
# 7     01.01.2022  01:00                        41.33
# 8     01.01.2022  02:00                        43.22
# 9     01.01.2022  03:00                        45.46
# 10    01.01.2022  04:00                        37.67
# ...          ...    ...                          ...
# 4344  30.06.2022  19:00                        479.0
# 4345  30.06.2022  20:00                        450.0
# 4346  30.06.2022  21:00                       394.21
# 4347  30.06.2022  22:00                       355.17
# 4348  30.06.2022  23:00                       258.08
#
# [4343 rows x 3 columns]

# %%
price_df_2020_ger["Deutschland/Luxemburg[€/MWh]"] = price_df_2020_ger["Deutschland/Luxemburg[€/MWh]"].astype(float)

# %%
dt_series = price_df_2020_ger['Date'] + ' ' + pd.Series(data=[str(item).replace(".", ":") for item in price_df_2020_ger['Time']], index=price_df_2020_ger.index)
dt_series = pd.to_datetime(dt_series,dayfirst= True)
dt_series
# Out:
# 6      2022-01-01 00:00:00
# 7      2022-01-01 01:00:00
# 8      2022-01-01 02:00:00
# 9      2022-01-01 03:00:00
# 10     2022-01-01 04:00:00
#                ...
# 4344   2022-06-30 19:00:00
# 4345   2022-06-30 20:00:00
# 4346   2022-06-30 21:00:00
# 4347   2022-06-30 22:00:00
# 4348   2022-06-30 23:00:00
# Length: 4343, dtype: datetime64[ns]

# %%
df = price_df_2020_ger.drop(columns=['Date', 'Time'], axis=1)
df.insert(loc=0, column='DateTime', value=dt_series)
df
# Out:
#                 DateTime  Deutschland/Luxemburg[€/MWh]
# 6    2022-01-01 00:00:00                         50.05
# 7    2022-01-01 01:00:00                         41.33
# 8    2022-01-01 02:00:00                         43.22
# 9    2022-01-01 03:00:00                         45.46
# 10   2022-01-01 04:00:00                         37.67
# ...                  ...                           ...
# 4344 2022-06-30 19:00:00                        479.00
# 4345 2022-06-30 20:00:00                        450.00
# 4346 2022-06-30 21:00:00                        394.21
# 4347 2022-06-30 22:00:00                        355.17
# 4348 2022-06-30 23:00:00                        258.08
#
# [4343 rows x 2 columns]

# %%
year_series = dt_series.dt.year
month_series = dt_series.dt.month
day_series = dt_series.dt.day
day_name_series = dt_series.dt.day_name()

# %%
df['Year'] = year_series
df['Month'] = month_series
df['Day'] = day_series
df['Day Name'] = day_name_series

# %%
df = df.sort_values(by='DateTime')
df
# Out:
#                 DateTime  Deutschland/Luxemburg[€/MWh]  Year  Month  Day  \
# 6    2022-01-01 00:00:00                         50.05  2022      1    1
# 7    2022-01-01 01:00:00                         41.33  2022      1    1
# 8    2022-01-01 02:00:00                         43.22  2022      1    1
# 9    2022-01-01 03:00:00                         45.46  2022      1    1
# 10   2022-01-01 04:00:00                         37.67  2022      1    1
# ...                  ...                           ...   ...    ...  ...
# 4344 2022-06-30 19:00:00                        479.00  2022      6   30
# 4345 2022-06-30 20:00:00                        450.00  2022      6   30
# 4346 2022-06-30 21:00:00                        394.21  2022      6   30
# 4347 2022-06-30 22:00:00                        355.17  2022      6   30
# 4348 2022-06-30 23:00:00                        258.08  2022      6   30
#
#       Day Name
# 6     Saturday
# 7     Saturday
# 8     Saturday
# 9     Saturday
# ...

# %%
group_month = df.groupby(by='Month',as_index = False)
group_month

# %%
group_month.agg(func=['mean', 'std', 'median'])
# Out:
#       Deutschland/Luxemburg[€/MWh]                         Year               \
#                               mean         std   median    mean  std  median
# Month
# 1                       167.726573   76.024414  172.315  2022.0  0.0  2022.0
# 2                       128.802679   63.016974  120.090  2022.0  0.0  2022.0
# 3                       252.006851  114.019194  245.030  2022.0  0.0  2022.0
# 4                       165.731903   72.055040  185.590  2022.0  0.0  2022.0
# 5                       177.476949   67.256987  192.675  2022.0  0.0  2022.0
# 6                       218.033236   85.154468  210.120  2022.0  0.0  2022.0
#
#              Day
#             mean       std median
# Month
# 1      16.000000  8.950289   16.0
# 2      14.500000  8.083764   14.5
# 3      15.985195  8.947197   16.0
# 4      15.500000  8.661458   15.5
# 5      16.000000  8.950289   16.0
# 6      15.500000  8.661458   15.5

# %%
months = df['DateTime'].dt.month_name().unique()
plt.figure(figsize=(15, 5))
plt.plot(group_month.mean()['Month'], group_month.mean()['Deutschland/Luxemburg[€/MWh]'],'r-o',label ="Germany")
plt.title(" German Price v/s Indian Price for the year 2022")
plt.ylabel("Deutschland/India[€/MWh]")
plt.xticks(ticks=group_month.median()['Month'], labels=months,rotation=45)



plt.plot(group_month_2022_new.mean()['Month'], group_month_2022_new.mean()['MCP (Rs/MWh)'],'b-o',label ="India")
plt.legend()
plt.savefig("German vs India 2022")

# %%
values = 50 + 60+80 +125 + 80 + 85
values/6
# Out:
# 80.0

# %%
a = 165 + 125 + 250 +175 +185 +225
a/6
# Out:
# 187.5

# %%
a = 65+60+50
a/3
# Out:
# 58.333333333333336

# %%
c=58.333333333333336 +80.0
c/2
# Out:
# 69.16666666666667

# %%
c= 120+175+215
c/3
# Out:
# 170.0

# %%
s=170+187.5
s/2
# Out:
# 178.75
